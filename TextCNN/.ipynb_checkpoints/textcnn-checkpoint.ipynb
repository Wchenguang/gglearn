# %%
import pandas as pd

data_path = './Tomatoes/'

data = pd.read_csv("%s%s" % (data_path, 'train.tsv'), sep = '\t')
test_data = pd.read_csv("%s%s" % (data_path, 'test.tsv'), sep = '\t')

import re
def clean(_str):
    return " ".join(re.findall("[0-9a-zA-Z]*", _str)).strip()
def split(_str):
    return _str.split()

data['Phrase'] = data['Phrase'].apply(clean)
test_data['Phrase'] = data['Phrase'].apply(clean)

def _len(_str):
    return len(_str.split())
data['phracelen'] = data['Phrase'].apply(_len)
data['phracelen'].describe()
# Out:
# count    156060.00000
# mean          6.89463
# std           6.57485
# min           0.00000
# 25%           2.00000
# 50%           4.00000
# 75%           9.00000
# max          48.00000
# Name: phracelen, dtype: float64

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits = 1, test_size = 0.2, train_size = 0.8, random_state = 22)

for train_index, dev_index in split.split(data, data[['Sentiment']]):
    dev_data = data.loc[dev_index]
    train_data = data.loc[train_index]
train_data.shape, dev_data.shape
# Out:
# ((124848, 5), (31212, 5))

# %%
import gensim
import numpy as np



def get_w2v(splited_corpus, w2v_size, min_count):
    '''
    func: 获取word2vec模型
    param: splited_corpus
        type: pd.Series
        detail: 应当为训练集中所有语料
    param: w2v_size
        type: int
        detail: w2v向量维度
    return: w2v_model
        type: gensim.models.Word2Vec
        detail: 训练的模型只可以使用其transform接口
    '''
    sentences = [x.split() for x in splited_corpus]
    model = gensim.models.Word2Vec(sentences, min_count=min_count, size=w2v_size)
    return model

def get_w2v_key_vev(w2v_model):
    vecs = []
    words = []
    for word in w2v_model.wv.vocab:
        vecs.append(w2v_model[word])
        words.append(word)
    return words, vecs

def get_x_index(x, words):
    res = []
    for inst in x:
        res.append(np.array([words.index(word) for word in inst.split() if word in words]))
    return res

def max_len(list_2d):
    maxlen = 0
    for arr in list_2d:
        if(len(arr) > maxlen):
            maxlen = len(arr)
    return maxlen

def mean_len(list_2d):
    mean_len = 0
    for arr in list_2d:
        mean_len += len(arr)
    return int(mean_len / len(list_2d))

def ceil2(num):
    res = 2
    while res < num:
        res *= 2
    return res

def padding(data2d, max_len, pad_val):
    res = []
    for index, seq in enumerate(data2d):
        if(len(seq) < max_len):
            res.append(np.concatenate([seq, np.full([max_len - len(seq)], pad_val)]))
        else:
            res.append(seq[:max_len])
    return res

def concat_list_h(list1, list2):
    res = []
    for i, ele in enumerate(list1):
        res.append(np.concatenate([ele, list2[i]]))
    return res

from sklearn.preprocessing import OneHotEncoder
oh_enc = OneHotEncoder()
train_y = np.array(list(train_data['Sentiment'])).reshape(-1, 1)
train_y = oh_enc.fit_transform(train_y).toarray()
dev_y = np.array(list(dev_data['Sentiment'])).reshape(-1, 1)
dev_y = oh_enc.fit_transform(dev_y).toarray()
corpus = list(train_data['Phrase'])
max_seq_len = ceil2(max_len(corpus))
mean_seq_len = mean_len(corpus)
print(max_seq_len, mean_seq_len)
max_seq_len = 16
w2v_model = get_w2v(corpus, 300, min_count = 1)
words, embedding_matrix = get_w2v_key_vev(w2v_model)
embedding_matrix.append([0 for i in range(len(embedding_matrix[0]))])

train_x = get_x_index(list(train_data['Phrase']), words)
train_x = padding(train_x, max_seq_len, len(embedding_matrix) - 1)

dev_x = get_x_index(list(dev_data['Phrase']), words)
dev_x = padding(dev_x, max_seq_len, len(embedding_matrix) - 1)
# Out:
# /home/dutir_2t/wangchenguang/anaconda3/envs/gpu-tf/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /home/dutir_2t/wangchenguang/anaconda3/envs/gpu-tf/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# 512 45
# /home/dutir_2t/wangchenguang/anaconda3/envs/gpu-tf/lib/python3.6/site-packages/ipykernel_launcher.py:27: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "1,2,3"

import tensorflow as tf
from keras.preprocessing import sequence
from keras.layers import Embedding
from datetime import datetime

class typical:
    def __init__(self, seq_len, num_classes, batch_seqs_num, embedding_matrix, embedding_size, filter_sizes,
                num_filters, conv_activate_fn = tf.nn.relu, fcl_activate_fn = tf.nn.relu, learning_rate = 0.01,
                n_epochs = 100, rate_decay_steps = 1000, rate_decay_rate = 0.99, regulation_rate= 0.0001,
                sum_root_dir = "tf_logs", drop_out_prob = 0.5):
        self.seq_len = seq_len
        self.num_classes = num_classes
        self.batch_seqs_num = batch_seqs_num
        self.embedding_matrix = embedding_matrix
        self.embedding_size = embedding_size
        self.filter_sizes = filter_sizes
        self.num_filters = num_filters
        self.conv_activate_fn = conv_activate_fn
        self.fcl_activate_fn = fcl_activate_fn
        self.learning_rate = learning_rate
        self.n_epochs = n_epochs
        self.rate_decay_steps = rate_decay_steps
        self.rate_decay_rate = rate_decay_rate
        self.regulation_rate = regulation_rate
        self.log_dir = self.log_dir(sum_root_dir)
        self.drop_out_prob = drop_out_prob
        self.graph = tf.Graph()
    
    def log_dir(self, root_logdir):
        now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
        log_dir = "{}/run-{}/".format(root_logdir, now)
        return log_dir
    
    def build(self):
        with self.graph.as_default(), tf.name_scope("TextCNN"):
            self.input_x = tf.placeholder(dtype = tf.int32, shape = [None, self.seq_len], name = "input_x")
            self.input_y = tf.placeholder(dtype = tf.int32, shape = [None, self.num_classes], name = "input_y")
            self.dropout_keep_prob = tf.placeholder(tf.float32, name="dropout_keep_prob")
            self.global_step = tf.Variable(0, trainable = False)
            self.learning_rate_ = tf.train.exponential_decay(
                self.learning_rate,
                self.global_step,
                self.rate_decay_steps,
                self.rate_decay_rate
            )
            with tf.device('/cpu:0'), tf.name_scope("embedding"):
                self.embedding_matrix_ = tf.constant(self.embedding_matrix, name = "embedding_matrix", dtype = tf.float32)
                self.embedded = tf.expand_dims(tf.nn.embedding_lookup(self.embedding_matrix_, self.input_x), -1,
                                               name = "embedded_output")
            self.pooled_outputs = []
            for filter_size in self.filter_sizes:
                with tf.name_scope("conv_maxpool"):
                    filter_shape = [filter_size, self.embedding_size, 1, self.num_filters]
                    filter_weight = tf.Variable(tf.truncated_normal(filter_shape, stddev = 0.1), name = "filter_weight")
                    filter_bias = tf.Variable(tf.truncated_normal([self.num_filters], stddev = 0.1), name = "filter_bias")
                    conv_output = self.conv_activate_fn(tf.nn.bias_add(tf.nn.conv2d(
                        self.embedded,
                        filter_weight,
                        strides = [1, 1, 1, 1],
                        padding = 'VALID',
                    ), filter_bias, name = "conv_output"), name = "act_conv_output")
                    pooled_output = tf.nn.max_pool(conv_output,
                                                  ksize = [1, self.seq_len - filter_size + 1, 1, 1],
                                                  strides = [1, 1, 1, 1],
                                                  padding = "VALID",
                                                  name = "pooled_output")
                    self.pooled_outputs.append(pooled_output)
            #拼接
            self.total_filters_num = self.num_filters * len(self.filter_sizes)
            self.concated_output = tf.concat(self.pooled_outputs, 3)
            self.reduced_concated_output = tf.reshape(self.concated_output, [-1, self.total_filters_num], 
                                                      name = "conv_maxpool_output")

            with tf.name_scope("dropout"):
                self.droped_conv_output = tf.nn.dropout(self.reduced_concated_output, self.dropout_keep_prob)

            with tf.name_scope("full_connect"):
                self.fcl_weight = tf.Variable(tf.truncated_normal([self.total_filters_num, self.num_classes],
                                                                 stddev = 0.1), name = 'fcl_weight')
                self.fcl_bias = tf.Variable(tf.constant(0.1, shape = [self.num_classes]), name = 'fcl_bias')
                self.fcl_output = tf.nn.bias_add(tf.matmul(self.droped_conv_output, self.fcl_weight),
                                                self.fcl_bias, name = "fcl_output")

            self.prediction = self.fcl_output
            with tf.name_scope("regulation"):
                self.regularizer = tf.contrib.layers.l2_regularizer(self.regulation_rate)
                self.regulation = self.regularizer(self.fcl_weight) + self.regularizer(self.fcl_bias)
            with tf.name_scope("loss"):
                self.loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
                        logits = self.prediction, labels = self.input_y,  
                    ), name = "cross_entrophy") + self.regulation
            with tf.name_scope("target"):
                self.train_correct = tf.equal(tf.arg_max(self.prediction, 1), tf.arg_max(self.input_y, 1), name = "correct")
                self.train_acc = tf.reduce_mean(tf.cast(self.train_correct, tf.float32), name = "acc")
            with tf.name_scope("summary"):
                self.loss_sum = tf.summary.scalar("loss", self.loss)
                self.acc_sum = tf.summary.scalar("acc", self.train_acc)
                self.sum = tf.summary.merge_all()
                self.filewriter = tf.summary.FileWriter(self.log_dir, tf.get_default_graph())
            self.optimizer = tf.train.AdamOptimizer(self.learning_rate_)
            self.train_step = self.optimizer.minimize(self.loss, global_step = self.global_step)
            
    
    def fit(self, x, y, dev_x = None, dev_y = None, test_x = None):
        self.x = x
        self.y = y
        self.dev_x = dev_x
        self.dev_y = dev_y
        self.test_x = test_x
    
    def train(self):
        print('tf log dir : ', self.log_dir)
        n_batches = int(np.ceil(len(self.x) / self.batch_seqs_num))
        batch_size = self.batch_seqs_num
        dev_feed_dict = {
            self.input_x : self.dev_x,
            self.input_y : self.dev_y,
            self.dropout_keep_prob : 1.0
        }
        train_feed_dict = {
            self.input_x : self.x[:10000],
            self.input_y : self.y[:10000],
            self.dropout_keep_prob : 1.0
        }
        config = tf.ConfigProto()
        config.gpu_options.allow_growth = True
        config.allow_soft_placement = True
        with tf.Session(config = config, graph = self.graph) as self.sess:
            tf.global_variables_initializer().run()
            for epoch in range(self.n_epochs):
                for batch_index in range(n_batches):
                    batch_x = self.x[batch_size * batch_index : (batch_index + 1) * batch_size]
                    batch_y = self.y[batch_size * batch_index : (batch_index + 1) * batch_size]
                    feed_dict = {
                        self.input_x : batch_x,
                        self.input_y : batch_y,
                        self.dropout_keep_prob : self.drop_out_prob
                    }
                    self.sess.run(self.train_step, feed_dict = feed_dict)
                    step = epoch * n_batches + batch_index
                print('train epoch %d / %d Done' % (epoch, self.n_epochs))
                if(epoch % 5 == 0):
                    print('dev acc', self.train_acc.eval(feed_dict = dev_feed_dict))
                    print('train loss', self.loss.eval(feed_dict = train_feed_dict))
                    dev_acc_str = self.acc_sum.eval(feed_dict = dev_feed_dict)
                    train_loss_str = self.loss_sum.eval(feed_dict = train_feed_dict)
                    self.filewriter.add_summary(dev_acc_str, step)
                    self.filewriter.add_summary(train_loss_str, step)
            
    
m = typical(max_seq_len, 5, 32, np.array(embedding_matrix), len(embedding_matrix[0]), [2,3,4,5], 128, learning_rate = 0.00018,
            n_epochs = 10000, rate_decay_steps = 500000, drop_out_prob = 0.4)
m.build()
m.fit(train_x, train_y, dev_x, dev_y)
m.train()
# Out:
# WARNING:tensorflow:From <ipython-input-5-d36ba792a63e>:97: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From <ipython-input-5-d36ba792a63e>:100: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# tf log dir :  tf_logs/run-20191117001151/
# train epoch 0 / 10000 Done
# dev acc 0.53735745
# train loss 1.1656975
# train epoch 1 / 10000 Done
# train epoch 2 / 10000 Done
# train epoch 3 / 10000 Done
# train epoch 4 / 10000 Done
# train epoch 5 / 10000 Done
# dev acc 0.56423813
# train loss 1.0802755
# train epoch 6 / 10000 Done
# train epoch 7 / 10000 Done
# train epoch 8 / 10000 Done
# train epoch 9 / 10000 Done
# train epoch 10 / 10000 Done
# dev acc 0.5755799
# train loss 1.0461062
# train epoch 11 / 10000 Done
# train epoch 12 / 10000 Done
# train epoch 13 / 10000 Done
# train epoch 14 / 10000 Done
# train epoch 15 / 10000 Done
# dev acc 0.58112264
# train loss 1.0208598
# train epoch 16 / 10000 Done
# train epoch 17 / 10000 Done
# train epoch 18 / 10000 Done
# train epoch 19 / 10000 Done
# train epoch 20 / 10000 Done
# dev acc 0.5859605
# train loss 1.002967
# train epoch 21 / 10000 Done
# train epoch 22 / 10000 Done
# train epoch 23 / 10000 Done
# train epoch 24 / 10000 Done
# train epoch 25 / 10000 Done
# dev acc 0.5871139
# train loss 0.9939181
# train epoch 26 / 10000 Done
# train epoch 27 / 10000 Done
# train epoch 28 / 10000 Done
# train epoch 29 / 10000 Done
# train epoch 30 / 10000 Done
# dev acc 0.59105474
# train loss 0.9786421
# train epoch 31 / 10000 Done
# train epoch 32 / 10000 Done
# train epoch 33 / 10000 Done
# train epoch 34 / 10000 Done
# train epoch 35 / 10000 Done
# dev acc 0.5935217
# train loss 0.97001255
# train epoch 36 / 10000 Done
# train epoch 37 / 10000 Done
# train epoch 38 / 10000 Done
# train epoch 39 / 10000 Done
# train epoch 40 / 10000 Done
# dev acc 0.5966295
# train loss 0.9571265
# train epoch 41 / 10000 Done
# train epoch 42 / 10000 Done
# train epoch 43 / 10000 Done
# train epoch 44 / 10000 Done
# train epoch 45 / 10000 Done
# dev acc 0.59624505
# train loss 0.954116
# train epoch 46 / 10000 Done
# train epoch 47 / 10000 Done
# train epoch 48 / 10000 Done
# train epoch 49 / 10000 Done
# train epoch 50 / 10000 Done
# dev acc 0.5985518
# train loss 0.94459033
# train epoch 51 / 10000 Done
# train epoch 52 / 10000 Done
# train epoch 53 / 10000 Done
# train epoch 54 / 10000 Done
# train epoch 55 / 10000 Done
# dev acc 0.59983337
# train loss 0.93937165
# train epoch 56 / 10000 Done
# train epoch 57 / 10000 Done
# train epoch 58 / 10000 Done
# train epoch 59 / 10000 Done
# train epoch 60 / 10000 Done
# dev acc 0.60012174
# train loss 0.9351722
# train epoch 61 / 10000 Done
# train epoch 62 / 10000 Done
# train epoch 63 / 10000 Done
# train epoch 64 / 10000 Done
# train epoch 65 / 10000 Done
# dev acc 0.6005062
# train loss 0.93223566
# train epoch 66 / 10000 Done
# train epoch 67 / 10000 Done
# train epoch 68 / 10000 Done
# train epoch 69 / 10000 Done
# train epoch 70 / 10000 Done
# dev acc 0.60387033
# train loss 0.9224331
# train epoch 71 / 10000 Done
# train epoch 72 / 10000 Done
# train epoch 73 / 10000 Done
# train epoch 74 / 10000 Done
# train epoch 75 / 10000 Done
# dev acc 0.6004101
# train loss 0.9223812
# train epoch 76 / 10000 Done
# train epoch 77 / 10000 Done
# train epoch 78 / 10000 Done
# train epoch 79 / 10000 Done
# train epoch 80 / 10000 Done
# dev acc 0.60367805
# train loss 0.9186569
# train epoch 81 / 10000 Done
# train epoch 82 / 10000 Done
# train epoch 83 / 10000 Done
# train epoch 84 / 10000 Done
# train epoch 85 / 10000 Done
# dev acc 0.6056004
# train loss 0.9170739
# train epoch 86 / 10000 Done
# train epoch 87 / 10000 Done
# train epoch 88 / 10000 Done
# train epoch 89 / 10000 Done
# train epoch 90 / 10000 Done
# dev acc 0.60483146
# train loss 0.90986776
# train epoch 91 / 10000 Done
# train epoch 92 / 10000 Done
# train epoch 93 / 10000 Done
# train epoch 94 / 10000 Done
# train epoch 95 / 10000 Done
# dev acc 0.6049596
# train loss 0.90845054
# train epoch 96 / 10000 Done
# train epoch 97 / 10000 Done
# train epoch 98 / 10000 Done
# train epoch 99 / 10000 Done
# train epoch 100 / 10000 Done
# dev acc 0.60624117
# train loss 0.9020477
# train epoch 101 / 10000 Done
# train epoch 102 / 10000 Done
# train epoch 103 / 10000 Done
# train epoch 104 / 10000 Done
# train epoch 105 / 10000 Done
# dev acc 0.60601693
# train loss 0.9005951
# train epoch 106 / 10000 Done
# train epoch 107 / 10000 Done
# train epoch 108 / 10000 Done
# train epoch 109 / 10000 Done
# train epoch 110 / 10000 Done
# dev acc 0.6082917
# train loss 0.8960651
# train epoch 111 / 10000 Done
# train epoch 112 / 10000 Done
# train epoch 113 / 10000 Done
# train epoch 114 / 10000 Done
# train epoch 115 / 10000 Done
# dev acc 0.6067538
# train loss 0.89830524
# train epoch 116 / 10000 Done
# train epoch 117 / 10000 Done
# train epoch 118 / 10000 Done
# train epoch 119 / 10000 Done
# train epoch 120 / 10000 Done
# dev acc 0.609381
# train loss 0.8929526
# train epoch 121 / 10000 Done
# train epoch 122 / 10000 Done
# train epoch 123 / 10000 Done
# train epoch 124 / 10000 Done
# train epoch 125 / 10000 Done
# dev acc 0.607715
# train loss 0.8912964
# train epoch 126 / 10000 Done
# train epoch 127 / 10000 Done
# train epoch 128 / 10000 Done
# train epoch 129 / 10000 Done
# train epoch 130 / 10000 Done
# dev acc 0.6089965
# train loss 0.8871423
# train epoch 131 / 10000 Done
# train epoch 132 / 10000 Done
# train epoch 133 / 10000 Done
# train epoch 134 / 10000 Done
# train epoch 135 / 10000 Done
# dev acc 0.60835576
# train loss 0.88668156
# train epoch 136 / 10000 Done
# train epoch 137 / 10000 Done
# train epoch 138 / 10000 Done
# train epoch 139 / 10000 Done
# train epoch 140 / 10000 Done
# dev acc 0.61024606
# train loss 0.88247657
# train epoch 141 / 10000 Done
# train epoch 142 / 10000 Done
# train epoch 143 / 10000 Done
# train epoch 144 / 10000 Done
# train epoch 145 / 10000 Done
# dev acc 0.6096694
# train loss 0.88060296
# train epoch 146 / 10000 Done
# train epoch 147 / 10000 Done
# train epoch 148 / 10000 Done
# train epoch 149 / 10000 Done
# train epoch 150 / 10000 Done
# dev acc 0.6117839
# train loss 0.88034904
# train epoch 151 / 10000 Done
# train epoch 152 / 10000 Done
# train epoch 153 / 10000 Done
# train epoch 154 / 10000 Done
# train epoch 155 / 10000 Done
# dev acc 0.609413
# train loss 0.8787275
# train epoch 156 / 10000 Done
# train epoch 157 / 10000 Done
# train epoch 158 / 10000 Done
# train epoch 159 / 10000 Done
# train epoch 160 / 10000 Done
# dev acc 0.6104063
# train loss 0.8768337
# train epoch 161 / 10000 Done
# train epoch 162 / 10000 Done
# train epoch 163 / 10000 Done
# train epoch 164 / 10000 Done
# train epoch 165 / 10000 Done
# dev acc 0.6121043
# train loss 0.8749887
# train epoch 166 / 10000 Done
# train epoch 167 / 10000 Done
# train epoch 168 / 10000 Done
# train epoch 169 / 10000 Done
# train epoch 170 / 10000 Done
# dev acc 0.61047035
# train loss 0.8775956
# train epoch 171 / 10000 Done
# train epoch 172 / 10000 Done
# train epoch 173 / 10000 Done
# train epoch 174 / 10000 Done
# train epoch 175 / 10000 Done
# dev acc 0.61171985
# train loss 0.8692639
# train epoch 176 / 10000 Done
# train epoch 177 / 10000 Done
# train epoch 178 / 10000 Done
# train epoch 179 / 10000 Done
# train epoch 180 / 10000 Done
# dev acc 0.6131616
# train loss 0.8714999
# train epoch 181 / 10000 Done
# train epoch 182 / 10000 Done
# train epoch 183 / 10000 Done
# train epoch 184 / 10000 Done
# train epoch 185 / 10000 Done
# dev acc 0.6132898
# train loss 0.86930233
# train epoch 186 / 10000 Done
# train epoch 187 / 10000 Done
# train epoch 188 / 10000 Done
# train epoch 189 / 10000 Done
# train epoch 190 / 10000 Done
# dev acc 0.6120082
# train loss 0.8672527
# train epoch 191 / 10000 Done
# train epoch 192 / 10000 Done
# train epoch 193 / 10000 Done
# train epoch 194 / 10000 Done
# train epoch 195 / 10000 Done
# dev acc 0.6125208
# train loss 0.8628608
# train epoch 196 / 10000 Done
# train epoch 197 / 10000 Done
# train epoch 198 / 10000 Done
# train epoch 199 / 10000 Done
# train epoch 200 / 10000 Done
# dev acc 0.61242473
# train loss 0.8654885
# train epoch 201 / 10000 Done
# train epoch 202 / 10000 Done
# train epoch 203 / 10000 Done
# train epoch 204 / 10000 Done
# train epoch 205 / 10000 Done
# dev acc 0.6132577
# train loss 0.8650942
# train epoch 206 / 10000 Done
# train epoch 207 / 10000 Done
# train epoch 208 / 10000 Done
# train epoch 209 / 10000 Done
# train epoch 210 / 10000 Done
# dev acc 0.6122966
# train loss 0.86362284
# train epoch 211 / 10000 Done
# train epoch 212 / 10000 Done
# train epoch 213 / 10000 Done
# train epoch 214 / 10000 Done
# train epoch 215 / 10000 Done
# dev acc 0.61261696
# train loss 0.86469203
# train epoch 216 / 10000 Done
# train epoch 217 / 10000 Done
# train epoch 218 / 10000 Done
# train epoch 219 / 10000 Done
# train epoch 220 / 10000 Done
# dev acc 0.61453927
# train loss 0.860119
# train epoch 221 / 10000 Done
# train epoch 222 / 10000 Done
# train epoch 223 / 10000 Done
# train epoch 224 / 10000 Done
# train epoch 225 / 10000 Done
# dev acc 0.61498785
# train loss 0.8572563
# train epoch 226 / 10000 Done
# train epoch 227 / 10000 Done
# train epoch 228 / 10000 Done
# train epoch 229 / 10000 Done
# train epoch 230 / 10000 Done
# dev acc 0.61312956
# train loss 0.85590315
# train epoch 231 / 10000 Done
# train epoch 232 / 10000 Done
# train epoch 233 / 10000 Done
# train epoch 234 / 10000 Done
# train epoch 235 / 10000 Done
# dev acc 0.6146995
# train loss 0.8549316
# train epoch 236 / 10000 Done
# train epoch 237 / 10000 Done
# train epoch 238 / 10000 Done
# train epoch 239 / 10000 Done
# train epoch 240 / 10000 Done
# dev acc 0.6127771
# train loss 0.85491806
# train epoch 241 / 10000 Done
# train epoch 242 / 10000 Done
# train epoch 243 / 10000 Done
# train epoch 244 / 10000 Done
# train epoch 245 / 10000 Done
# dev acc 0.6149558
# train loss 0.8531865
# train epoch 246 / 10000 Done
# train epoch 247 / 10000 Done
# train epoch 248 / 10000 Done
# train epoch 249 / 10000 Done
# train epoch 250 / 10000 Done
# dev acc 0.61534023
# train loss 0.85221887
# train epoch 251 / 10000 Done
# train epoch 252 / 10000 Done
# train epoch 253 / 10000 Done
# train epoch 254 / 10000 Done
# train epoch 255 / 10000 Done
# dev acc 0.61344993
# train loss 0.8511357
# train epoch 256 / 10000 Done
# train epoch 257 / 10000 Done
# train epoch 258 / 10000 Done
# train epoch 259 / 10000 Done
# train epoch 260 / 10000 Done
# dev acc 0.6152121
# train loss 0.8492853
# train epoch 261 / 10000 Done
# train epoch 262 / 10000 Done
# train epoch 263 / 10000 Done
# train epoch 264 / 10000 Done
# train epoch 265 / 10000 Done
# dev acc 0.61591697
# train loss 0.8514799
# train epoch 266 / 10000 Done
# train epoch 267 / 10000 Done
# train epoch 268 / 10000 Done
# train epoch 269 / 10000 Done
# train epoch 270 / 10000 Done
# dev acc 0.6132257
# train loss 0.8509546
# train epoch 271 / 10000 Done
# train epoch 272 / 10000 Done
# train epoch 273 / 10000 Done
# train epoch 274 / 10000 Done
# train epoch 275 / 10000 Done
# dev acc 0.61508393
# train loss 0.8463423
# train epoch 276 / 10000 Done
# train epoch 277 / 10000 Done
# train epoch 278 / 10000 Done
# train epoch 279 / 10000 Done
# train epoch 280 / 10000 Done
# dev acc 0.6149558
# train loss 0.8473944
# train epoch 281 / 10000 Done
# train epoch 282 / 10000 Done
# train epoch 283 / 10000 Done
# train epoch 284 / 10000 Done
# train epoch 285 / 10000 Done
# dev acc 0.6171024
# train loss 0.8501079
# train epoch 286 / 10000 Done
# train epoch 287 / 10000 Done
# train epoch 288 / 10000 Done
# train epoch 289 / 10000 Done
# train epoch 290 / 10000 Done
# dev acc 0.61566067
# train loss 0.84659815
# train epoch 291 / 10000 Done
# train epoch 292 / 10000 Done
# train epoch 293 / 10000 Done
# train epoch 294 / 10000 Done
# train epoch 295 / 10000 Done
# dev acc 0.6153723
# train loss 0.845748
# train epoch 296 / 10000 Done
# train epoch 297 / 10000 Done
# train epoch 298 / 10000 Done
# train epoch 299 / 10000 Done
# train epoch 300 / 10000 Done
# dev acc 0.61620533
# train loss 0.84276915
# train epoch 301 / 10000 Done
# train epoch 302 / 10000 Done
# train epoch 303 / 10000 Done
# train epoch 304 / 10000 Done
# train epoch 305 / 10000 Done
# dev acc 0.6154364
# train loss 0.84457564
# train epoch 306 / 10000 Done
# train epoch 307 / 10000 Done
# train epoch 308 / 10000 Done
# train epoch 309 / 10000 Done
# train epoch 310 / 10000 Done
# dev acc 0.6177432
# train loss 0.8442133
# train epoch 311 / 10000 Done
# train epoch 312 / 10000 Done
# train epoch 313 / 10000 Done
# train epoch 314 / 10000 Done
# train epoch 315 / 10000 Done
# dev acc 0.6168461
# train loss 0.84034973
# train epoch 316 / 10000 Done
# train epoch 317 / 10000 Done
# train epoch 318 / 10000 Done
# train epoch 319 / 10000 Done
# train epoch 320 / 10000 Done
# dev acc 0.6169422
# train loss 0.83956647
# train epoch 321 / 10000 Done
# train epoch 322 / 10000 Done
# train epoch 323 / 10000 Done
# train epoch 324 / 10000 Done
# train epoch 325 / 10000 Done
# dev acc 0.61739075
# train loss 0.84007865
# train epoch 326 / 10000 Done
# train epoch 327 / 10000 Done
# train epoch 328 / 10000 Done
# train epoch 329 / 10000 Done
# train epoch 330 / 10000 Done
# dev acc 0.6158849
# train loss 0.8363337
# train epoch 331 / 10000 Done
# train epoch 332 / 10000 Done
# train epoch 333 / 10000 Done
# train epoch 334 / 10000 Done
# train epoch 335 / 10000 Done
# dev acc 0.61761504
# train loss 0.83555543
# train epoch 336 / 10000 Done
# train epoch 337 / 10000 Done
# train epoch 338 / 10000 Done
# train epoch 339 / 10000 Done
# train epoch 340 / 10000 Done
# dev acc 0.61838394
# train loss 0.8371686
# train epoch 341 / 10000 Done
# train epoch 342 / 10000 Done
# train epoch 343 / 10000 Done
# train epoch 344 / 10000 Done
# train epoch 345 / 10000 Done
# dev acc 0.61764705
# train loss 0.8359444
# train epoch 346 / 10000 Done
# train epoch 347 / 10000 Done
# train epoch 348 / 10000 Done
# train epoch 349 / 10000 Done
# train epoch 350 / 10000 Done
# dev acc 0.6171985
# train loss 0.8334322
# train epoch 351 / 10000 Done
# train epoch 352 / 10000 Done
# train epoch 353 / 10000 Done
# train epoch 354 / 10000 Done
# train epoch 355 / 10000 Done
# dev acc 0.61723053
# train loss 0.83532524
# train epoch 356 / 10000 Done
# train epoch 357 / 10000 Done
# train epoch 358 / 10000 Done
# train epoch 359 / 10000 Done
# train epoch 360 / 10000 Done
# dev acc 0.61642957
# train loss 0.8372744
# train epoch 361 / 10000 Done
# train epoch 362 / 10000 Done
# train epoch 363 / 10000 Done
# train epoch 364 / 10000 Done
# train epoch 365 / 10000 Done
# dev acc 0.6171024
# train loss 0.8314632
# train epoch 366 / 10000 Done
# train epoch 367 / 10000 Done
# train epoch 368 / 10000 Done
# train epoch 369 / 10000 Done
# train epoch 370 / 10000 Done
# dev acc 0.61642957
# train loss 0.83418256
# train epoch 371 / 10000 Done
# train epoch 372 / 10000 Done
# train epoch 373 / 10000 Done
# train epoch 374 / 10000 Done
# train epoch 375 / 10000 Done
# dev acc 0.617583
# train loss 0.83212584
# train epoch 376 / 10000 Done
# train epoch 377 / 10000 Done
# train epoch 378 / 10000 Done
# train epoch 379 / 10000 Done
# train epoch 380 / 10000 Done
# dev acc 0.6182558
# train loss 0.83207107
# train epoch 381 / 10000 Done
# train epoch 382 / 10000 Done
# train epoch 383 / 10000 Done
# train epoch 384 / 10000 Done
# train epoch 385 / 10000 Done
# dev acc 0.6162694
# train loss 0.83439654
# train epoch 386 / 10000 Done
# train epoch 387 / 10000 Done
# train epoch 388 / 10000 Done
# train epoch 389 / 10000 Done
# train epoch 390 / 10000 Done
# dev acc 0.61905676
# train loss 0.83127743
# train epoch 391 / 10000 Done
# train epoch 392 / 10000 Done
# train epoch 393 / 10000 Done
# train epoch 394 / 10000 Done
# train epoch 395 / 10000 Done
# dev acc 0.6168461
# train loss 0.8292691
# train epoch 396 / 10000 Done
# train epoch 397 / 10000 Done
# train epoch 398 / 10000 Done
# train epoch 399 / 10000 Done
# train epoch 400 / 10000 Done
# dev acc 0.61601305
# train loss 0.82974076
# train epoch 401 / 10000 Done
# train epoch 402 / 10000 Done
# train epoch 403 / 10000 Done
# train epoch 404 / 10000 Done
# train epoch 405 / 10000 Done
# dev acc 0.61755097
# train loss 0.83186054
# train epoch 406 / 10000 Done
# train epoch 407 / 10000 Done
# train epoch 408 / 10000 Done
# train epoch 409 / 10000 Done
# train epoch 410 / 10000 Done
# dev acc 0.616782
# train loss 0.8304547
# train epoch 411 / 10000 Done
# train epoch 412 / 10000 Done
# train epoch 413 / 10000 Done
# train epoch 414 / 10000 Done
# train epoch 415 / 10000 Done
# dev acc 0.61764705
# train loss 0.8283775
# train epoch 416 / 10000 Done
# train epoch 417 / 10000 Done
# train epoch 418 / 10000 Done
# train epoch 419 / 10000 Done
# train epoch 420 / 10000 Done
# dev acc 0.6189927
# train loss 0.8279395
# train epoch 421 / 10000 Done
# train epoch 422 / 10000 Done
# train epoch 423 / 10000 Done
# train epoch 424 / 10000 Done
# train epoch 425 / 10000 Done
# dev acc 0.6177752
# train loss 0.8255381
# train epoch 426 / 10000 Done
# train epoch 427 / 10000 Done
# train epoch 428 / 10000 Done
# train epoch 429 / 10000 Done
# train epoch 430 / 10000 Done
# dev acc 0.61639756
# train loss 0.82863295
# train epoch 431 / 10000 Done
# train epoch 432 / 10000 Done
# train epoch 433 / 10000 Done
# train epoch 434 / 10000 Done
# train epoch 435 / 10000 Done
# dev acc 0.6187043
# train loss 0.8259831
# train epoch 436 / 10000 Done
# train epoch 437 / 10000 Done
# train epoch 438 / 10000 Done
# train epoch 439 / 10000 Done
# train epoch 440 / 10000 Done
# dev acc 0.6163335
# train loss 0.82659584
# train epoch 441 / 10000 Done
# train epoch 442 / 10000 Done
# train epoch 443 / 10000 Done
# train epoch 444 / 10000 Done
# train epoch 445 / 10000 Done
# dev acc 0.61905676
# train loss 0.82479453
# train epoch 446 / 10000 Done
# train epoch 447 / 10000 Done
# train epoch 448 / 10000 Done
# train epoch 449 / 10000 Done
# train epoch 450 / 10000 Done
# dev acc 0.6178393
# train loss 0.82546693
# train epoch 451 / 10000 Done
# train epoch 452 / 10000 Done
# train epoch 453 / 10000 Done
# train epoch 454 / 10000 Done
# train epoch 455 / 10000 Done
# dev acc 0.61912084
# train loss 0.8231052
# train epoch 456 / 10000 Done
# train epoch 457 / 10000 Done
# train epoch 458 / 10000 Done
# train epoch 459 / 10000 Done
# train epoch 460 / 10000 Done
# dev acc 0.6177752
# train loss 0.8245464
# train epoch 461 / 10000 Done
# train epoch 462 / 10000 Done
# train epoch 463 / 10000 Done
# train epoch 464 / 10000 Done
# train epoch 465 / 10000 Done
# dev acc 0.61905676
# train loss 0.8236244
# train epoch 466 / 10000 Done
# train epoch 467 / 10000 Done
# train epoch 468 / 10000 Done
# train epoch 469 / 10000 Done
# train epoch 470 / 10000 Done
# dev acc 0.6172946
# train loss 0.8221105
# train epoch 471 / 10000 Done
# train epoch 472 / 10000 Done
# train epoch 473 / 10000 Done
# train epoch 474 / 10000 Done
# train epoch 475 / 10000 Done
# dev acc 0.6180956
# train loss 0.82028353
# train epoch 476 / 10000 Done
# train epoch 477 / 10000 Done
# train epoch 478 / 10000 Done
# train epoch 479 / 10000 Done
# train epoch 480 / 10000 Done
# dev acc 0.6176791
# train loss 0.81885064
# train epoch 481 / 10000 Done
# train epoch 482 / 10000 Done
# train epoch 483 / 10000 Done
# train epoch 484 / 10000 Done
# train epoch 485 / 10000 Done
# dev acc 0.6196335
# train loss 0.819765
# train epoch 486 / 10000 Done
# train epoch 487 / 10000 Done
# train epoch 488 / 10000 Done
# train epoch 489 / 10000 Done
# train epoch 490 / 10000 Done
# dev acc 0.61806357
# train loss 0.8224282
# train epoch 491 / 10000 Done
# train epoch 492 / 10000 Done
# train epoch 493 / 10000 Done
# train epoch 494 / 10000 Done
# train epoch 495 / 10000 Done
# dev acc 0.6189286
# train loss 0.8187224
# train epoch 496 / 10000 Done
# train epoch 497 / 10000 Done
# train epoch 498 / 10000 Done
# train epoch 499 / 10000 Done
# train epoch 500 / 10000 Done
# dev acc 0.61857617
# train loss 0.81900746
# train epoch 501 / 10000 Done
# train epoch 502 / 10000 Done
# train epoch 503 / 10000 Done
# train epoch 504 / 10000 Done
# train epoch 505 / 10000 Done
# dev acc 0.61780727
# train loss 0.8203619
# train epoch 506 / 10000 Done
# train epoch 507 / 10000 Done
# train epoch 508 / 10000 Done
# train epoch 509 / 10000 Done
# train epoch 510 / 10000 Done
# dev acc 0.6207869
# train loss 0.8178399
# train epoch 511 / 10000 Done
# train epoch 512 / 10000 Done
# train epoch 513 / 10000 Done
# train epoch 514 / 10000 Done
# train epoch 515 / 10000 Done
# dev acc 0.61764705
# train loss 0.8186113
# train epoch 516 / 10000 Done
# train epoch 517 / 10000 Done
# train epoch 518 / 10000 Done
# train epoch 519 / 10000 Done
# train epoch 520 / 10000 Done
# dev acc 0.6182558
# train loss 0.81890124
# train epoch 521 / 10000 Done
# train epoch 522 / 10000 Done
# train epoch 523 / 10000 Done
# train epoch 524 / 10000 Done
# train epoch 525 / 10000 Done
# dev acc 0.6194733
# train loss 0.81551105
# train epoch 526 / 10000 Done
# train epoch 527 / 10000 Done
# train epoch 528 / 10000 Done
# train epoch 529 / 10000 Done
# train epoch 530 / 10000 Done
# dev acc 0.6189607
# train loss 0.8181672
# train epoch 531 / 10000 Done
# train epoch 532 / 10000 Done
# train epoch 533 / 10000 Done
# train epoch 534 / 10000 Done
# train epoch 535 / 10000 Done
# dev acc 0.6189927
# train loss 0.813498
# train epoch 536 / 10000 Done
# train epoch 537 / 10000 Done
# train epoch 538 / 10000 Done
# train epoch 539 / 10000 Done
# train epoch 540 / 10000 Done
# dev acc 0.61812764
# train loss 0.8114954
# train epoch 541 / 10000 Done
# train epoch 542 / 10000 Done
# train epoch 543 / 10000 Done
# train epoch 544 / 10000 Done
# train epoch 545 / 10000 Done
# dev acc 0.6198257
# train loss 0.813377
# train epoch 546 / 10000 Done
# train epoch 547 / 10000 Done
# train epoch 548 / 10000 Done
# train epoch 549 / 10000 Done
# train epoch 550 / 10000 Done
# dev acc 0.6187684
# train loss 0.81425625
# train epoch 551 / 10000 Done
# train epoch 552 / 10000 Done
# train epoch 553 / 10000 Done
# train epoch 554 / 10000 Done
# train epoch 555 / 10000 Done
# dev acc 0.6189927
# train loss 0.81271344
# train epoch 556 / 10000 Done
# train epoch 557 / 10000 Done
# train epoch 558 / 10000 Done
# train epoch 559 / 10000 Done
# train epoch 560 / 10000 Done
# dev acc 0.6189927
# train loss 0.8120234
# train epoch 561 / 10000 Done
# train epoch 562 / 10000 Done
# train epoch 563 / 10000 Done
# train epoch 564 / 10000 Done
# train epoch 565 / 10000 Done
# dev acc 0.6187043
# train loss 0.81366456
# train epoch 566 / 10000 Done
# train epoch 567 / 10000 Done
# train epoch 568 / 10000 Done
# train epoch 569 / 10000 Done
# train epoch 570 / 10000 Done
# dev acc 0.6189286
# train loss 0.81416875
# train epoch 571 / 10000 Done
# train epoch 572 / 10000 Done
# train epoch 573 / 10000 Done
# train epoch 574 / 10000 Done
# train epoch 575 / 10000 Done
# dev acc 0.6194412
# train loss 0.8130478
# train epoch 576 / 10000 Done
# train epoch 577 / 10000 Done
# train epoch 578 / 10000 Done
# train epoch 579 / 10000 Done
# train epoch 580 / 10000 Done
# dev acc 0.6194412
# train loss 0.812895
# train epoch 581 / 10000 Done
# train epoch 582 / 10000 Done
# train epoch 583 / 10000 Done
# train epoch 584 / 10000 Done
# train epoch 585 / 10000 Done
# dev acc 0.61928105
# train loss 0.8110188
# train epoch 586 / 10000 Done
# train epoch 587 / 10000 Done
# train epoch 588 / 10000 Done
# train epoch 589 / 10000 Done
# train epoch 590 / 10000 Done
# dev acc 0.6188325
# train loss 0.811032
# train epoch 591 / 10000 Done
# train epoch 592 / 10000 Done
# train epoch 593 / 10000 Done
# train epoch 594 / 10000 Done
# train epoch 595 / 10000 Done
# dev acc 0.61912084
# train loss 0.8102377
# train epoch 596 / 10000 Done
# train epoch 597 / 10000 Done
# train epoch 598 / 10000 Done
# train epoch 599 / 10000 Done
# train epoch 600 / 10000 Done
# dev acc 0.6208189
# train loss 0.8093836
# train epoch 601 / 10000 Done
# train epoch 602 / 10000 Done
# train epoch 603 / 10000 Done
# train epoch 604 / 10000 Done
# train epoch 605 / 10000 Done
# dev acc 0.6194092
# train loss 0.8086174
# train epoch 606 / 10000 Done
# train epoch 607 / 10000 Done
# train epoch 608 / 10000 Done
# train epoch 609 / 10000 Done
# train epoch 610 / 10000 Done
# dev acc 0.619217
# train loss 0.8094772
# train epoch 611 / 10000 Done
# train epoch 612 / 10000 Done
# train epoch 613 / 10000 Done
# train epoch 614 / 10000 Done
# train epoch 615 / 10000 Done
# dev acc 0.6191849
# train loss 0.8101715
# train epoch 616 / 10000 Done
# train epoch 617 / 10000 Done
# train epoch 618 / 10000 Done
# train epoch 619 / 10000 Done
# train epoch 620 / 10000 Done
# dev acc 0.61979365
# train loss 0.80894715
# train epoch 621 / 10000 Done
# train epoch 622 / 10000 Done
# train epoch 623 / 10000 Done
# train epoch 624 / 10000 Done
# train epoch 625 / 10000 Done
# dev acc 0.6179674
# train loss 0.80975
# train epoch 626 / 10000 Done
# train epoch 627 / 10000 Done
# train epoch 628 / 10000 Done
# train epoch 629 / 10000 Done
# train epoch 630 / 10000 Done
# dev acc 0.6198257
# train loss 0.80690026
# train epoch 631 / 10000 Done
# train epoch 632 / 10000 Done
# train epoch 633 / 10000 Done
# train epoch 634 / 10000 Done
# train epoch 635 / 10000 Done
# dev acc 0.6203063
# train loss 0.8070792
# train epoch 636 / 10000 Done
# train epoch 637 / 10000 Done
# train epoch 638 / 10000 Done
# train epoch 639 / 10000 Done
# train epoch 640 / 10000 Done
# dev acc 0.6201461
# train loss 0.8072451
# train epoch 641 / 10000 Done
# train epoch 642 / 10000 Done
# train epoch 643 / 10000 Done
# train epoch 644 / 10000 Done
# train epoch 645 / 10000 Done
# dev acc 0.61931306
# train loss 0.80692625
# train epoch 646 / 10000 Done
# train epoch 647 / 10000 Done
# train epoch 648 / 10000 Done
# train epoch 649 / 10000 Done
# train epoch 650 / 10000 Done
# dev acc 0.6179354
# train loss 0.8079602
# train epoch 651 / 10000 Done
# train epoch 652 / 10000 Done
# train epoch 653 / 10000 Done
# train epoch 654 / 10000 Done
# train epoch 655 / 10000 Done
# dev acc 0.6201141
# train loss 0.80717
# train epoch 656 / 10000 Done
# train epoch 657 / 10000 Done
# train epoch 658 / 10000 Done
# train epoch 659 / 10000 Done
# train epoch 660 / 10000 Done
# dev acc 0.6216199
# train loss 0.8036506
# train epoch 661 / 10000 Done
# train epoch 662 / 10000 Done
# train epoch 663 / 10000 Done
# train epoch 664 / 10000 Done
# train epoch 665 / 10000 Done
# dev acc 0.62126744
# train loss 0.80415493
# train epoch 666 / 10000 Done
# train epoch 667 / 10000 Done
# train epoch 668 / 10000 Done
# train epoch 669 / 10000 Done
# train epoch 670 / 10000 Done
# dev acc 0.61905676
# train loss 0.8043194
# train epoch 671 / 10000 Done
# train epoch 672 / 10000 Done
# train epoch 673 / 10000 Done
# train epoch 674 / 10000 Done
# train epoch 675 / 10000 Done
# dev acc 0.6194412
# train loss 0.80788016
# train epoch 676 / 10000 Done
# train epoch 677 / 10000 Done
# train epoch 678 / 10000 Done
# train epoch 679 / 10000 Done
# train epoch 680 / 10000 Done
# dev acc 0.62142766
# train loss 0.8021802
# train epoch 681 / 10000 Done
# train epoch 682 / 10000 Done
# train epoch 683 / 10000 Done
# train epoch 684 / 10000 Done
# train epoch 685 / 10000 Done
# dev acc 0.6196976
# train loss 0.8043827
# train epoch 686 / 10000 Done
# train epoch 687 / 10000 Done
# train epoch 688 / 10000 Done
# train epoch 689 / 10000 Done
# train epoch 690 / 10000 Done
# dev acc 0.6207869
# train loss 0.8015309
# train epoch 691 / 10000 Done
# train epoch 692 / 10000 Done
# train epoch 693 / 10000 Done
# train epoch 694 / 10000 Done
# train epoch 695 / 10000 Done
# dev acc 0.6187364
# train loss 0.80080646
# train epoch 696 / 10000 Done
# train epoch 697 / 10000 Done
# train epoch 698 / 10000 Done
# train epoch 699 / 10000 Done
# train epoch 700 / 10000 Done
# dev acc 0.62004995
# train loss 0.80180174
# train epoch 701 / 10000 Done
# train epoch 702 / 10000 Done
# train epoch 703 / 10000 Done
# train epoch 704 / 10000 Done
# train epoch 705 / 10000 Done
# dev acc 0.62142766
# train loss 0.79900837
# train epoch 706 / 10000 Done
# train epoch 707 / 10000 Done
# train epoch 708 / 10000 Done
# train epoch 709 / 10000 Done
# train epoch 710 / 10000 Done
# dev acc 0.6218762
# train loss 0.7996701
# train epoch 711 / 10000 Done
# train epoch 712 / 10000 Done
# train epoch 713 / 10000 Done
# train epoch 714 / 10000 Done
# train epoch 715 / 10000 Done
# dev acc 0.6206587
# train loss 0.8012476
# train epoch 716 / 10000 Done
# train epoch 717 / 10000 Done
# train epoch 718 / 10000 Done
# train epoch 719 / 10000 Done
# train epoch 720 / 10000 Done
# dev acc 0.6195694
# train loss 0.8020191
# train epoch 721 / 10000 Done
# train epoch 722 / 10000 Done
# train epoch 723 / 10000 Done
# train epoch 724 / 10000 Done
# train epoch 725 / 10000 Done
# dev acc 0.6199218
# train loss 0.8013025
# train epoch 726 / 10000 Done
# train epoch 727 / 10000 Done
# train epoch 728 / 10000 Done
# train epoch 729 / 10000 Done
# train epoch 730 / 10000 Done
# dev acc 0.62213254
# train loss 0.8005546
# train epoch 731 / 10000 Done
# train epoch 732 / 10000 Done
# train epoch 733 / 10000 Done
# train epoch 734 / 10000 Done
# train epoch 735 / 10000 Done
# dev acc 0.6201461
# train loss 0.8011867
# train epoch 736 / 10000 Done
# train epoch 737 / 10000 Done
# train epoch 738 / 10000 Done
# train epoch 739 / 10000 Done
# train epoch 740 / 10000 Done
# dev acc 0.6210432
# train loss 0.8015645
# train epoch 741 / 10000 Done
# train epoch 742 / 10000 Done
# train epoch 743 / 10000 Done
# train epoch 744 / 10000 Done
# train epoch 745 / 10000 Done
# dev acc 0.6206587
# train loss 0.79785234
# train epoch 746 / 10000 Done
# train epoch 747 / 10000 Done
# train epoch 748 / 10000 Done
# train epoch 749 / 10000 Done
# train epoch 750 / 10000 Done
# dev acc 0.61979365
# train loss 0.7995198
# train epoch 751 / 10000 Done
# train epoch 752 / 10000 Done
# train epoch 753 / 10000 Done
# train epoch 754 / 10000 Done
# train epoch 755 / 10000 Done
# dev acc 0.6190888
# train loss 0.79900813
# train epoch 756 / 10000 Done
# train epoch 757 / 10000 Done
# train epoch 758 / 10000 Done
# train epoch 759 / 10000 Done
# train epoch 760 / 10000 Done
# dev acc 0.619249
# train loss 0.8016089
# train epoch 761 / 10000 Done
# train epoch 762 / 10000 Done
# train epoch 763 / 10000 Done
# train epoch 764 / 10000 Done
# train epoch 765 / 10000 Done
# dev acc 0.6196014
# train loss 0.799629
# train epoch 766 / 10000 Done
# train epoch 767 / 10000 Done
# train epoch 768 / 10000 Done
# train epoch 769 / 10000 Done
# train epoch 770 / 10000 Done
# dev acc 0.62027425
# train loss 0.7995119
# train epoch 771 / 10000 Done
# train epoch 772 / 10000 Done
# train epoch 773 / 10000 Done
# train epoch 774 / 10000 Done
# train epoch 775 / 10000 Done
# dev acc 0.62117136
# train loss 0.7960855
# train epoch 776 / 10000 Done
# train epoch 777 / 10000 Done
# train epoch 778 / 10000 Done
# train epoch 779 / 10000 Done
# train epoch 780 / 10000 Done
# dev acc 0.6218442
# train loss 0.79846853
# train epoch 781 / 10000 Done
# train epoch 782 / 10000 Done
# train epoch 783 / 10000 Done
# train epoch 784 / 10000 Done
# train epoch 785 / 10000 Done
# dev acc 0.62017816
# train loss 0.7958114
# train epoch 786 / 10000 Done
# train epoch 787 / 10000 Done
# train epoch 788 / 10000 Done
# train epoch 789 / 10000 Done
# train epoch 790 / 10000 Done
# dev acc 0.6213636
# train loss 0.7969385
# train epoch 791 / 10000 Done
# train epoch 792 / 10000 Done
# train epoch 793 / 10000 Done
# train epoch 794 / 10000 Done
# train epoch 795 / 10000 Done
# dev acc 0.6204665
# train loss 0.7988582
# train epoch 796 / 10000 Done
# train epoch 797 / 10000 Done
# train epoch 798 / 10000 Done
# train epoch 799 / 10000 Done
# train epoch 800 / 10000 Done
# dev acc 0.6205946
# train loss 0.79546887
# train epoch 801 / 10000 Done
# train epoch 802 / 10000 Done
# train epoch 803 / 10000 Done
# train epoch 804 / 10000 Done
# train epoch 805 / 10000 Done
# dev acc 0.6213636
# train loss 0.7954732
# train epoch 806 / 10000 Done
# train epoch 807 / 10000 Done
# train epoch 808 / 10000 Done
# train epoch 809 / 10000 Done
# train epoch 810 / 10000 Done
# dev acc 0.62094706
# train loss 0.79630727
# train epoch 811 / 10000 Done
# train epoch 812 / 10000 Done
# train epoch 813 / 10000 Done
# train epoch 814 / 10000 Done
# train epoch 815 / 10000 Done
# dev acc 0.6196014
# train loss 0.79700863
# train epoch 816 / 10000 Done
# train epoch 817 / 10000 Done
# train epoch 818 / 10000 Done
# train epoch 819 / 10000 Done
# train epoch 820 / 10000 Done
# dev acc 0.61931306
# train loss 0.7964754
# train epoch 821 / 10000 Done
# train epoch 822 / 10000 Done
# train epoch 823 / 10000 Done
# train epoch 824 / 10000 Done
# train epoch 825 / 10000 Done
# dev acc 0.62049854
# train loss 0.79358727
# train epoch 826 / 10000 Done
# train epoch 827 / 10000 Done
# train epoch 828 / 10000 Done
# train epoch 829 / 10000 Done
# train epoch 830 / 10000 Done
# dev acc 0.62097913
# train loss 0.7961029
# train epoch 831 / 10000 Done
# train epoch 832 / 10000 Done
# train epoch 833 / 10000 Done
# train epoch 834 / 10000 Done
# train epoch 835 / 10000 Done
# dev acc 0.6221005
# train loss 0.7940833
# train epoch 836 / 10000 Done
# train epoch 837 / 10000 Done
# train epoch 838 / 10000 Done
# train epoch 839 / 10000 Done
# train epoch 840 / 10000 Done
# dev acc 0.6212995
# train loss 0.7912512
# train epoch 841 / 10000 Done
# train epoch 842 / 10000 Done
# train epoch 843 / 10000 Done
# train epoch 844 / 10000 Done
# train epoch 845 / 10000 Done
# dev acc 0.6215238
# train loss 0.7911848
# train epoch 846 / 10000 Done
# train epoch 847 / 10000 Done
# train epoch 848 / 10000 Done
# train epoch 849 / 10000 Done
# train epoch 850 / 10000 Done
# dev acc 0.6203704
# train loss 0.7925851
# train epoch 851 / 10000 Done
# train epoch 852 / 10000 Done
# train epoch 853 / 10000 Done
# train epoch 854 / 10000 Done
# train epoch 855 / 10000 Done
# dev acc 0.6199539
# train loss 0.7924307
# train epoch 856 / 10000 Done
# train epoch 857 / 10000 Done
# train epoch 858 / 10000 Done
# train epoch 859 / 10000 Done
# train epoch 860 / 10000 Done
# dev acc 0.6221966
# train loss 0.7926091
# train epoch 861 / 10000 Done
# train epoch 862 / 10000 Done
# train epoch 863 / 10000 Done
# train epoch 864 / 10000 Done
# train epoch 865 / 10000 Done
# dev acc 0.62238884
# train loss 0.7926356
# train epoch 866 / 10000 Done
# train epoch 867 / 10000 Done
# train epoch 868 / 10000 Done
# train epoch 869 / 10000 Done
# train epoch 870 / 10000 Done
# dev acc 0.6203704
# train loss 0.79315305
# train epoch 871 / 10000 Done
# train epoch 872 / 10000 Done
# train epoch 873 / 10000 Done
# train epoch 874 / 10000 Done
# train epoch 875 / 10000 Done
# dev acc 0.6211393
# train loss 0.7906315
# train epoch 876 / 10000 Done
# train epoch 877 / 10000 Done
# train epoch 878 / 10000 Done
# train epoch 879 / 10000 Done
# train epoch 880 / 10000 Done
# dev acc 0.6227413
# train loss 0.79261523
# train epoch 881 / 10000 Done
# train epoch 882 / 10000 Done
# train epoch 883 / 10000 Done
# train epoch 884 / 10000 Done
# train epoch 885 / 10000 Done
# dev acc 0.62194026
# train loss 0.79195744
# train epoch 886 / 10000 Done
# train epoch 887 / 10000 Done
# train epoch 888 / 10000 Done
# train epoch 889 / 10000 Done
# train epoch 890 / 10000 Done
# dev acc 0.6199218
# train loss 0.7923966
# train epoch 891 / 10000 Done
# train epoch 892 / 10000 Done
# train epoch 893 / 10000 Done
# train epoch 894 / 10000 Done
# train epoch 895 / 10000 Done
# dev acc 0.62017816
# train loss 0.78973377
# train epoch 896 / 10000 Done
# train epoch 897 / 10000 Done
# train epoch 898 / 10000 Done
# train epoch 899 / 10000 Done
# train epoch 900 / 10000 Done
# dev acc 0.62165195
# train loss 0.7918636
# train epoch 901 / 10000 Done
# train epoch 902 / 10000 Done
# train epoch 903 / 10000 Done
# train epoch 904 / 10000 Done
# train epoch 905 / 10000 Done
# dev acc 0.62024224
# train loss 0.7906241
# train epoch 906 / 10000 Done
# train epoch 907 / 10000 Done
# train epoch 908 / 10000 Done
# train epoch 909 / 10000 Done
# train epoch 910 / 10000 Done
# dev acc 0.6222286
# train loss 0.792007
# train epoch 911 / 10000 Done
# train epoch 912 / 10000 Done
# train epoch 913 / 10000 Done
# train epoch 914 / 10000 Done
# train epoch 915 / 10000 Done
# dev acc 0.6210432
# train loss 0.791804
# train epoch 916 / 10000 Done
# train epoch 917 / 10000 Done
# train epoch 918 / 10000 Done
# train epoch 919 / 10000 Done
# train epoch 920 / 10000 Done
# dev acc 0.6223568
# train loss 0.789157
# train epoch 921 / 10000 Done
# train epoch 922 / 10000 Done
# train epoch 923 / 10000 Done
# train epoch 924 / 10000 Done
# train epoch 925 / 10000 Done
# dev acc 0.62168396
# train loss 0.7895894
# train epoch 926 / 10000 Done
# train epoch 927 / 10000 Done
# train epoch 928 / 10000 Done
# train epoch 929 / 10000 Done
# train epoch 930 / 10000 Done
# dev acc 0.62168396
# train loss 0.78797317
# train epoch 931 / 10000 Done
# train epoch 932 / 10000 Done
# train epoch 933 / 10000 Done
# train epoch 934 / 10000 Done
# train epoch 935 / 10000 Done
# dev acc 0.6211393
# train loss 0.7895977
# train epoch 936 / 10000 Done
# train epoch 937 / 10000 Done
# train epoch 938 / 10000 Done
# train epoch 939 / 10000 Done
# train epoch 940 / 10000 Done
# dev acc 0.6217801
# train loss 0.7894986
# train epoch 941 / 10000 Done
# train epoch 942 / 10000 Done
# train epoch 943 / 10000 Done
# train epoch 944 / 10000 Done
# train epoch 945 / 10000 Done
# dev acc 0.6216199
# train loss 0.7886941
# train epoch 946 / 10000 Done
# train epoch 947 / 10000 Done
# train epoch 948 / 10000 Done
# train epoch 949 / 10000 Done
# train epoch 950 / 10000 Done
# dev acc 0.6221966
# train loss 0.7874771
# train epoch 951 / 10000 Done
# train epoch 952 / 10000 Done
# train epoch 953 / 10000 Done
# train epoch 954 / 10000 Done
# train epoch 955 / 10000 Done
# dev acc 0.62117136
# train loss 0.7874846
# train epoch 956 / 10000 Done
# train epoch 957 / 10000 Done
# train epoch 958 / 10000 Done
# train epoch 959 / 10000 Done
# train epoch 960 / 10000 Done
# dev acc 0.6220364
# train loss 0.78656495
# train epoch 961 / 10000 Done
# train epoch 962 / 10000 Done
# train epoch 963 / 10000 Done
# train epoch 964 / 10000 Done
# train epoch 965 / 10000 Done
# dev acc 0.62149173
# train loss 0.78616405
# train epoch 966 / 10000 Done
# train epoch 967 / 10000 Done
# train epoch 968 / 10000 Done
# train epoch 969 / 10000 Done
# train epoch 970 / 10000 Done
# dev acc 0.6234782
# train loss 0.7876631
# train epoch 971 / 10000 Done
# train epoch 972 / 10000 Done
# train epoch 973 / 10000 Done
# train epoch 974 / 10000 Done
# train epoch 975 / 10000 Done
# dev acc 0.62200433
# train loss 0.78962016
# train epoch 976 / 10000 Done
# train epoch 977 / 10000 Done
# train epoch 978 / 10000 Done
# train epoch 979 / 10000 Done
# train epoch 980 / 10000 Done
# dev acc 0.6213636
# train loss 0.787452
# train epoch 981 / 10000 Done
# train epoch 982 / 10000 Done
# train epoch 983 / 10000 Done
# train epoch 984 / 10000 Done
# train epoch 985 / 10000 Done
# dev acc 0.62123543
# train loss 0.78332317
# train epoch 986 / 10000 Done
# train epoch 987 / 10000 Done
# train epoch 988 / 10000 Done
# train epoch 989 / 10000 Done
# train epoch 990 / 10000 Done
# dev acc 0.62174803
# train loss 0.7856225
# train epoch 991 / 10000 Done
# train epoch 992 / 10000 Done
# train epoch 993 / 10000 Done
# train epoch 994 / 10000 Done
# train epoch 995 / 10000 Done
# dev acc 0.6226131
# train loss 0.787464
# train epoch 996 / 10000 Done
# train epoch 997 / 10000 Done
# train epoch 998 / 10000 Done
# train epoch 999 / 10000 Done
# train epoch 1000 / 10000 Done
# dev acc 0.6205946
# train loss 0.7851155
# train epoch 1001 / 10000 Done
# train epoch 1002 / 10000 Done
# train epoch 1003 / 10000 Done
# train epoch 1004 / 10000 Done
# train epoch 1005 / 10000 Done
# dev acc 0.62206846
# train loss 0.78513736
# train epoch 1006 / 10000 Done
# train epoch 1007 / 10000 Done
# train epoch 1008 / 10000 Done
# train epoch 1009 / 10000 Done
# train epoch 1010 / 10000 Done
# dev acc 0.6221005
# train loss 0.7868838
# train epoch 1011 / 10000 Done
# train epoch 1012 / 10000 Done
# train epoch 1013 / 10000 Done
# train epoch 1014 / 10000 Done
# train epoch 1015 / 10000 Done
# dev acc 0.62024224
# train loss 0.78639275
# train epoch 1016 / 10000 Done
# train epoch 1017 / 10000 Done
# train epoch 1018 / 10000 Done
# train epoch 1019 / 10000 Done
# train epoch 1020 / 10000 Done
# dev acc 0.62149173
# train loss 0.78498715
# train epoch 1021 / 10000 Done
# train epoch 1022 / 10000 Done
# train epoch 1023 / 10000 Done
# train epoch 1024 / 10000 Done
# train epoch 1025 / 10000 Done
# dev acc 0.6218762
# train loss 0.78543
# train epoch 1026 / 10000 Done
# train epoch 1027 / 10000 Done
# train epoch 1028 / 10000 Done
# train epoch 1029 / 10000 Done
# train epoch 1030 / 10000 Done
# dev acc 0.6218121
# train loss 0.78269976
# train epoch 1031 / 10000 Done
# train epoch 1032 / 10000 Done
# train epoch 1033 / 10000 Done
# train epoch 1034 / 10000 Done
# train epoch 1035 / 10000 Done
# dev acc 0.622549
# train loss 0.784334
# train epoch 1036 / 10000 Done
# train epoch 1037 / 10000 Done
# train epoch 1038 / 10000 Done
# train epoch 1039 / 10000 Done
# train epoch 1040 / 10000 Done
# dev acc 0.6226131
# train loss 0.7856562
# train epoch 1041 / 10000 Done
# train epoch 1042 / 10000 Done
# train epoch 1043 / 10000 Done
# train epoch 1044 / 10000 Done
# train epoch 1045 / 10000 Done
# dev acc 0.6208189
# train loss 0.78548384
# train epoch 1046 / 10000 Done
# train epoch 1047 / 10000 Done
# train epoch 1048 / 10000 Done
# train epoch 1049 / 10000 Done
# train epoch 1050 / 10000 Done
# dev acc 0.622517
# train loss 0.78570783
# train epoch 1051 / 10000 Done
# train epoch 1052 / 10000 Done
# train epoch 1053 / 10000 Done
# train epoch 1054 / 10000 Done
# train epoch 1055 / 10000 Done
# dev acc 0.62075484
# train loss 0.78539056
# train epoch 1056 / 10000 Done
# train epoch 1057 / 10000 Done
# train epoch 1058 / 10000 Done
# train epoch 1059 / 10000 Done
# train epoch 1060 / 10000 Done
# dev acc 0.6226131
# train loss 0.78233135
# train epoch 1061 / 10000 Done
# train epoch 1062 / 10000 Done
# train epoch 1063 / 10000 Done
# train epoch 1064 / 10000 Done
# train epoch 1065 / 10000 Done
# dev acc 0.62267715
# train loss 0.78385586
# train epoch 1066 / 10000 Done
# train epoch 1067 / 10000 Done
# train epoch 1068 / 10000 Done
# train epoch 1069 / 10000 Done
# train epoch 1070 / 10000 Done
# dev acc 0.6222286
# train loss 0.7817129
# train epoch 1071 / 10000 Done
# train epoch 1072 / 10000 Done
# train epoch 1073 / 10000 Done
# train epoch 1074 / 10000 Done
# train epoch 1075 / 10000 Done
# dev acc 0.6217801
# train loss 0.78361714
# train epoch 1076 / 10000 Done
# train epoch 1077 / 10000 Done
# train epoch 1078 / 10000 Done
# train epoch 1079 / 10000 Done
# train epoch 1080 / 10000 Done
# dev acc 0.6218442
# train loss 0.7825485
# train epoch 1081 / 10000 Done
# train epoch 1082 / 10000 Done
# train epoch 1083 / 10000 Done
# train epoch 1084 / 10000 Done
# train epoch 1085 / 10000 Done
# dev acc 0.62283736
# train loss 0.78249454
# train epoch 1086 / 10000 Done
# train epoch 1087 / 10000 Done
# train epoch 1088 / 10000 Done
# train epoch 1089 / 10000 Done
# train epoch 1090 / 10000 Done
# dev acc 0.6221966
# train loss 0.7839642
# train epoch 1091 / 10000 Done
# train epoch 1092 / 10000 Done
# train epoch 1093 / 10000 Done
# train epoch 1094 / 10000 Done
# train epoch 1095 / 10000 Done
# dev acc 0.62126744
# train loss 0.78171766
# train epoch 1096 / 10000 Done
# train epoch 1097 / 10000 Done
# train epoch 1098 / 10000 Done
# train epoch 1099 / 10000 Done
# train epoch 1100 / 10000 Done
# dev acc 0.62117136
# train loss 0.7821173
# train epoch 1101 / 10000 Done
# train epoch 1102 / 10000 Done
# train epoch 1103 / 10000 Done
# train epoch 1104 / 10000 Done
# train epoch 1105 / 10000 Done
# dev acc 0.6229655
# train loss 0.78250366
# train epoch 1106 / 10000 Done
# train epoch 1107 / 10000 Done
# train epoch 1108 / 10000 Done
# train epoch 1109 / 10000 Done
# train epoch 1110 / 10000 Done
# dev acc 0.62123543
# train loss 0.7826546
# train epoch 1111 / 10000 Done
# train epoch 1112 / 10000 Done
# train epoch 1113 / 10000 Done
# train epoch 1114 / 10000 Done
# train epoch 1115 / 10000 Done
# dev acc 0.6196655
# train loss 0.7820548
# train epoch 1116 / 10000 Done
# train epoch 1117 / 10000 Done
# train epoch 1118 / 10000 Done
# train epoch 1119 / 10000 Done
# train epoch 1120 / 10000 Done
# dev acc 0.62469566
# train loss 0.7793951
# train epoch 1121 / 10000 Done
# train epoch 1122 / 10000 Done
# train epoch 1123 / 10000 Done
# train epoch 1124 / 10000 Done
# train epoch 1125 / 10000 Done
# dev acc 0.622517
# train loss 0.7827034
# train epoch 1126 / 10000 Done
# train epoch 1127 / 10000 Done
# train epoch 1128 / 10000 Done
# train epoch 1129 / 10000 Done
# train epoch 1130 / 10000 Done
# dev acc 0.621716
# train loss 0.7806977
# train epoch 1131 / 10000 Done
# train epoch 1132 / 10000 Done
# train epoch 1133 / 10000 Done
# train epoch 1134 / 10000 Done
# train epoch 1135 / 10000 Done
# dev acc 0.62232476
# train loss 0.7819008
# train epoch 1136 / 10000 Done
# train epoch 1137 / 10000 Done
# train epoch 1138 / 10000 Done
# train epoch 1139 / 10000 Done
# train epoch 1140 / 10000 Done
# dev acc 0.6229976
# train loss 0.7802365
# train epoch 1141 / 10000 Done
# train epoch 1142 / 10000 Done
# train epoch 1143 / 10000 Done
# train epoch 1144 / 10000 Done
# train epoch 1145 / 10000 Done
# dev acc 0.6219723
# train loss 0.77923906
# train epoch 1146 / 10000 Done
# train epoch 1147 / 10000 Done
# train epoch 1148 / 10000 Done
# train epoch 1149 / 10000 Done
# train epoch 1150 / 10000 Done
# dev acc 0.6227413
# train loss 0.7777475
# train epoch 1151 / 10000 Done
# train epoch 1152 / 10000 Done
# train epoch 1153 / 10000 Done
# train epoch 1154 / 10000 Done
# train epoch 1155 / 10000 Done
# dev acc 0.6224529
# train loss 0.78154
# train epoch 1156 / 10000 Done
# train epoch 1157 / 10000 Done
# train epoch 1158 / 10000 Done
# train epoch 1159 / 10000 Done
# train epoch 1160 / 10000 Done
# dev acc 0.6212995
# train loss 0.7805357
# train epoch 1161 / 10000 Done
# train epoch 1162 / 10000 Done
# train epoch 1163 / 10000 Done
# train epoch 1164 / 10000 Done
# train epoch 1165 / 10000 Done
# dev acc 0.62267715
# train loss 0.77930105
# train epoch 1166 / 10000 Done
# train epoch 1167 / 10000 Done
# train epoch 1168 / 10000 Done
# train epoch 1169 / 10000 Done
# train epoch 1170 / 10000 Done
# dev acc 0.6229335
# train loss 0.7790941
# train epoch 1171 / 10000 Done
# train epoch 1172 / 10000 Done
# train epoch 1173 / 10000 Done
# train epoch 1174 / 10000 Done
# train epoch 1175 / 10000 Done
# dev acc 0.6232859
# train loss 0.77678007
# train epoch 1176 / 10000 Done
# train epoch 1177 / 10000 Done
# train epoch 1178 / 10000 Done
# train epoch 1179 / 10000 Done
# train epoch 1180 / 10000 Done
# dev acc 0.6229655
# train loss 0.7796511
# train epoch 1181 / 10000 Done
# train epoch 1182 / 10000 Done
# train epoch 1183 / 10000 Done
# train epoch 1184 / 10000 Done
# train epoch 1185 / 10000 Done
# dev acc 0.6241189
# train loss 0.77958816
# train epoch 1186 / 10000 Done
# train epoch 1187 / 10000 Done
# train epoch 1188 / 10000 Done
# train epoch 1189 / 10000 Done
# train epoch 1190 / 10000 Done
# dev acc 0.62383056
# train loss 0.78037
# train epoch 1191 / 10000 Done
# train epoch 1192 / 10000 Done
# train epoch 1193 / 10000 Done
# train epoch 1194 / 10000 Done
# train epoch 1195 / 10000 Done
# dev acc 0.6227413
# train loss 0.7785679
# train epoch 1196 / 10000 Done
# train epoch 1197 / 10000 Done
# train epoch 1198 / 10000 Done
# train epoch 1199 / 10000 Done
# train epoch 1200 / 10000 Done
# dev acc 0.6221966
# train loss 0.77971184
# train epoch 1201 / 10000 Done
# train epoch 1202 / 10000 Done
# train epoch 1203 / 10000 Done
# train epoch 1204 / 10000 Done
# train epoch 1205 / 10000 Done
# dev acc 0.6245034
# train loss 0.7795412
# train epoch 1206 / 10000 Done
# train epoch 1207 / 10000 Done
# train epoch 1208 / 10000 Done
# train epoch 1209 / 10000 Done
# train epoch 1210 / 10000 Done
# dev acc 0.6234782
# train loss 0.77836305
# train epoch 1211 / 10000 Done
# train epoch 1212 / 10000 Done
# train epoch 1213 / 10000 Done
# train epoch 1214 / 10000 Done
# train epoch 1215 / 10000 Done
# dev acc 0.6234141
# train loss 0.7750489
# train epoch 1216 / 10000 Done
# train epoch 1217 / 10000 Done
# train epoch 1218 / 10000 Done
# train epoch 1219 / 10000 Done
# train epoch 1220 / 10000 Done
# dev acc 0.6229976
# train loss 0.7825691
# train epoch 1221 / 10000 Done
# train epoch 1222 / 10000 Done
# train epoch 1223 / 10000 Done
# train epoch 1224 / 10000 Done
# train epoch 1225 / 10000 Done
# dev acc 0.6210752
# train loss 0.778233
# train epoch 1226 / 10000 Done
# train epoch 1227 / 10000 Done
# train epoch 1228 / 10000 Done
# train epoch 1229 / 10000 Done
# train epoch 1230 / 10000 Done
# dev acc 0.6232859
# train loss 0.7765059
# train epoch 1231 / 10000 Done
# train epoch 1232 / 10000 Done
# train epoch 1233 / 10000 Done
# train epoch 1234 / 10000 Done
# train epoch 1235 / 10000 Done
# dev acc 0.6229655
# train loss 0.77468383
# train epoch 1236 / 10000 Done
# train epoch 1237 / 10000 Done
# train epoch 1238 / 10000 Done
# train epoch 1239 / 10000 Done
# train epoch 1240 / 10000 Done
# dev acc 0.62363833
# train loss 0.77419674
# train epoch 1241 / 10000 Done
# train epoch 1242 / 10000 Done
# train epoch 1243 / 10000 Done
# train epoch 1244 / 10000 Done
# train epoch 1245 / 10000 Done
# dev acc 0.62421507
# train loss 0.77525795
# train epoch 1246 / 10000 Done
# train epoch 1247 / 10000 Done
# train epoch 1248 / 10000 Done
# train epoch 1249 / 10000 Done
# train epoch 1250 / 10000 Done
# dev acc 0.62283736
# train loss 0.7770031
# train epoch 1251 / 10000 Done
# train epoch 1252 / 10000 Done
# train epoch 1253 / 10000 Done
# train epoch 1254 / 10000 Done
# train epoch 1255 / 10000 Done
# dev acc 0.62213254
# train loss 0.77599555
# train epoch 1256 / 10000 Done
# train epoch 1257 / 10000 Done
# train epoch 1258 / 10000 Done
# train epoch 1259 / 10000 Done
# train epoch 1260 / 10000 Done
# dev acc 0.6232539
# train loss 0.7767003
# train epoch 1261 / 10000 Done
# train epoch 1262 / 10000 Done
# train epoch 1263 / 10000 Done
# train epoch 1264 / 10000 Done
# train epoch 1265 / 10000 Done
# dev acc 0.62165195
# train loss 0.77675784
# train epoch 1266 / 10000 Done
# train epoch 1267 / 10000 Done
# train epoch 1268 / 10000 Done
# train epoch 1269 / 10000 Done
# train epoch 1270 / 10000 Done
# dev acc 0.6212995
# train loss 0.7785147
# train epoch 1271 / 10000 Done
# train epoch 1272 / 10000 Done
# train epoch 1273 / 10000 Done
# train epoch 1274 / 10000 Done
# train epoch 1275 / 10000 Done
# dev acc 0.62267715
# train loss 0.7774617
# train epoch 1276 / 10000 Done
# train epoch 1277 / 10000 Done
# ...
# train epoch 6230 / 10000 Done
# dev acc 0.6291811
# train loss 0.7068264
# train epoch 6231 / 10000 Done
# train epoch 6232 / 10000 Done
# train epoch 6233 / 10000 Done
# train epoch 6234 / 10000 Done
# train epoch 6235 / 10000 Done
# dev acc 0.62834805
# train loss 0.7059798
# train epoch 6236 / 10000 Done
# train epoch 6237 / 10000 Done
# train epoch 6238 / 10000 Done
# train epoch 6239 / 10000 Done
# train epoch 6240 / 10000 Done
# dev acc 0.6268102
# train loss 0.70635
# train epoch 6241 / 10000 Done
# train epoch 6242 / 10000 Done
# train epoch 6243 / 10000 Done
# train epoch 6244 / 10000 Done
# train epoch 6245 / 10000 Done
# dev acc 0.62805974
# train loss 0.70589375
# train epoch 6246 / 10000 Done
# train epoch 6247 / 10000 Done
# train epoch 6248 / 10000 Done
# train epoch 6249 / 10000 Done
# train epoch 6250 / 10000 Done
# dev acc 0.62690634
# train loss 0.70638025
# train epoch 6251 / 10000 Done
# train epoch 6252 / 10000 Done
# train epoch 6253 / 10000 Done
# train epoch 6254 / 10000 Done
# train epoch 6255 / 10000 Done
# dev acc 0.6281879
# train loss 0.7056602
# train epoch 6256 / 10000 Done
# train epoch 6257 / 10000 Done
# train epoch 6258 / 10000 Done
# train epoch 6259 / 10000 Done
# train epoch 6260 / 10000 Done
# dev acc 0.62690634
# train loss 0.70626044
# train epoch 6261 / 10000 Done
# train epoch 6262 / 10000 Done
# train epoch 6263 / 10000 Done
# train epoch 6264 / 10000 Done
# train epoch 6265 / 10000 Done
# dev acc 0.62767524
# train loss 0.7070163
# train epoch 6266 / 10000 Done
# train epoch 6267 / 10000 Done
# train epoch 6268 / 10000 Done
# train epoch 6269 / 10000 Done
# train epoch 6270 / 10000 Done
# dev acc 0.62876457
# train loss 0.70542717
# train epoch 6271 / 10000 Done
# train epoch 6272 / 10000 Done
# train epoch 6273 / 10000 Done
# train epoch 6274 / 10000 Done
# train epoch 6275 / 10000 Done
# dev acc 0.6280277
# train loss 0.70577693
# train epoch 6276 / 10000 Done
# train epoch 6277 / 10000 Done
# train epoch 6278 / 10000 Done
# train epoch 6279 / 10000 Done
# train epoch 6280 / 10000 Done
# dev acc 0.62719464
# train loss 0.7048394
# train epoch 6281 / 10000 Done
# train epoch 6282 / 10000 Done
# train epoch 6283 / 10000 Done
# train epoch 6284 / 10000 Done
# train epoch 6285 / 10000 Done
# dev acc 0.62716264
# train loss 0.7074421
# train epoch 6286 / 10000 Done
# train epoch 6287 / 10000 Done
# train epoch 6288 / 10000 Done
# train epoch 6289 / 10000 Done
# train epoch 6290 / 10000 Done
# dev acc 0.6267141
# train loss 0.706597
# train epoch 6291 / 10000 Done
# train epoch 6292 / 10000 Done
# train epoch 6293 / 10000 Done
# train epoch 6294 / 10000 Done
# train epoch 6295 / 10000 Done
# dev acc 0.6292772
# train loss 0.70609784
# train epoch 6296 / 10000 Done
# train epoch 6297 / 10000 Done
# train epoch 6298 / 10000 Done
# train epoch 6299 / 10000 Done
# train epoch 6300 / 10000 Done
# dev acc 0.6284442
# train loss 0.7050242
# train epoch 6301 / 10000 Done
# train epoch 6302 / 10000 Done
# train epoch 6303 / 10000 Done
# train epoch 6304 / 10000 Done
# train epoch 6305 / 10000 Done
# dev acc 0.62831604
# train loss 0.70670694
# train epoch 6306 / 10000 Done
# train epoch 6307 / 10000 Done
# train epoch 6308 / 10000 Done
# train epoch 6309 / 10000 Done
# train epoch 6310 / 10000 Done
# dev acc 0.62690634
# train loss 0.70657897
# train epoch 6311 / 10000 Done
# train epoch 6312 / 10000 Done
# train epoch 6313 / 10000 Done
# train epoch 6314 / 10000 Done
# train epoch 6315 / 10000 Done
# dev acc 0.6277393
# train loss 0.7076851
# train epoch 6316 / 10000 Done
# train epoch 6317 / 10000 Done
# train epoch 6318 / 10000 Done
# train epoch 6319 / 10000 Done
# train epoch 6320 / 10000 Done
# dev acc 0.6277714
# train loss 0.7085156
# train epoch 6321 / 10000 Done
# train epoch 6322 / 10000 Done
# train epoch 6323 / 10000 Done
# train epoch 6324 / 10000 Done
# train epoch 6325 / 10000 Done
# dev acc 0.62793154
# train loss 0.7081359
# train epoch 6326 / 10000 Done
# train epoch 6327 / 10000 Done
# train epoch 6328 / 10000 Done
# train epoch 6329 / 10000 Done
# train epoch 6330 / 10000 Done
# dev acc 0.6284442
# train loss 0.70555025
# train epoch 6331 / 10000 Done
# train epoch 6332 / 10000 Done
# train epoch 6333 / 10000 Done
# train epoch 6334 / 10000 Done
# train epoch 6335 / 10000 Done
# dev acc 0.6289248
# train loss 0.7075903
# train epoch 6336 / 10000 Done
# train epoch 6337 / 10000 Done
# train epoch 6338 / 10000 Done
# train epoch 6339 / 10000 Done
# train epoch 6340 / 10000 Done
# dev acc 0.62831604
# train loss 0.7047487
# train epoch 6341 / 10000 Done
# train epoch 6342 / 10000 Done
# train epoch 6343 / 10000 Done
# train epoch 6344 / 10000 Done
# train epoch 6345 / 10000 Done
# dev acc 0.62735486
# train loss 0.70617115
# train epoch 6346 / 10000 Done
# train epoch 6347 / 10000 Done
# train epoch 6348 / 10000 Done
# train epoch 6349 / 10000 Done
# train epoch 6350 / 10000 Done
# dev acc 0.62665004
# train loss 0.7042333
# train epoch 6351 / 10000 Done
# train epoch 6352 / 10000 Done
# train epoch 6353 / 10000 Done
# train epoch 6354 / 10000 Done
# train epoch 6355 / 10000 Done
# dev acc 0.627451
# train loss 0.70421505
# train epoch 6356 / 10000 Done
# train epoch 6357 / 10000 Done
# train epoch 6358 / 10000 Done
# train epoch 6359 / 10000 Done
# train epoch 6360 / 10000 Done
# dev acc 0.62805974
# train loss 0.7056821
# train epoch 6361 / 10000 Done
# train epoch 6362 / 10000 Done
# train epoch 6363 / 10000 Done
# train epoch 6364 / 10000 Done
# train epoch 6365 / 10000 Done
# dev acc 0.62834805
# train loss 0.7043348
# train epoch 6366 / 10000 Done
# train epoch 6367 / 10000 Done
# train epoch 6368 / 10000 Done
# train epoch 6369 / 10000 Done
# train epoch 6370 / 10000 Done
# dev acc 0.6287005
# train loss 0.70632195
# train epoch 6371 / 10000 Done
# train epoch 6372 / 10000 Done
# train epoch 6373 / 10000 Done
# train epoch 6374 / 10000 Done
# train epoch 6375 / 10000 Done
# dev acc 0.6288607
# train loss 0.7054177
# train epoch 6376 / 10000 Done
# train epoch 6377 / 10000 Done
# train epoch 6378 / 10000 Done
# train epoch 6379 / 10000 Done
# train epoch 6380 / 10000 Done
# dev acc 0.62709856
# train loss 0.7055758
# train epoch 6381 / 10000 Done
# train epoch 6382 / 10000 Done
# train epoch 6383 / 10000 Done
# train epoch 6384 / 10000 Done
# train epoch 6385 / 10000 Done
# dev acc 0.6264898
# train loss 0.70564073
# train epoch 6386 / 10000 Done
# train epoch 6387 / 10000 Done
# train epoch 6388 / 10000 Done
# train epoch 6389 / 10000 Done
# train epoch 6390 / 10000 Done
# dev acc 0.6283801
# train loss 0.7036213
# train epoch 6391 / 10000 Done
# train epoch 6392 / 10000 Done
# train epoch 6393 / 10000 Done
# train epoch 6394 / 10000 Done
# train epoch 6395 / 10000 Done
# dev acc 0.62687427
# train loss 0.7046722
# train epoch 6396 / 10000 Done
# train epoch 6397 / 10000 Done
# train epoch 6398 / 10000 Done
# train epoch 6399 / 10000 Done
# train epoch 6400 / 10000 Done
# dev acc 0.6281238
# train loss 0.70592153
# train epoch 6401 / 10000 Done
# train epoch 6402 / 10000 Done
# train epoch 6403 / 10000 Done
# train epoch 6404 / 10000 Done
# train epoch 6405 / 10000 Done
# dev acc 0.6286685
# train loss 0.70600575
# train epoch 6406 / 10000 Done
# train epoch 6407 / 10000 Done
# train epoch 6408 / 10000 Done
# train epoch 6409 / 10000 Done
# train epoch 6410 / 10000 Done
# dev acc 0.6288927
# train loss 0.70609844
# train epoch 6411 / 10000 Done
# train epoch 6412 / 10000 Done
# train epoch 6413 / 10000 Done
# train epoch 6414 / 10000 Done
# train epoch 6415 / 10000 Done
# dev acc 0.62825197
# train loss 0.70436734
# train epoch 6416 / 10000 Done
# train epoch 6417 / 10000 Done
# train epoch 6418 / 10000 Done
# train epoch 6419 / 10000 Done
# train epoch 6420 / 10000 Done
# dev acc 0.6284442
# train loss 0.706698
# train epoch 6421 / 10000 Done
# train epoch 6422 / 10000 Done
# train epoch 6423 / 10000 Done
# train epoch 6424 / 10000 Done
# train epoch 6425 / 10000 Done
# dev acc 0.62799567
# train loss 0.70361483
# train epoch 6426 / 10000 Done
# train epoch 6427 / 10000 Done
# train epoch 6428 / 10000 Done
# train epoch 6429 / 10000 Done
# train epoch 6430 / 10000 Done
# dev acc 0.6270665
# train loss 0.7094563
# train epoch 6431 / 10000 Done
# train epoch 6432 / 10000 Done
# train epoch 6433 / 10000 Done
# train epoch 6434 / 10000 Done
# train epoch 6435 / 10000 Done
# dev acc 0.6282199
# train loss 0.7080418
# train epoch 6436 / 10000 Done
# train epoch 6437 / 10000 Done
# train epoch 6438 / 10000 Done
# train epoch 6439 / 10000 Done
# train epoch 6440 / 10000 Done
# dev acc 0.629149
# train loss 0.70533645
# train epoch 6441 / 10000 Done
# train epoch 6442 / 10000 Done
# train epoch 6443 / 10000 Done
# train epoch 6444 / 10000 Done
# train epoch 6445 / 10000 Done
# dev acc 0.62805974
# train loss 0.70461065
# train epoch 6446 / 10000 Done
# train epoch 6447 / 10000 Done
# train epoch 6448 / 10000 Done
# train epoch 6449 / 10000 Done
# train epoch 6450 / 10000 Done
# dev acc 0.62735486
# train loss 0.70360446
# train epoch 6451 / 10000 Done
# train epoch 6452 / 10000 Done
# train epoch 6453 / 10000 Done
# train epoch 6454 / 10000 Done
# train epoch 6455 / 10000 Done
# dev acc 0.62786746
# train loss 0.7053503
# train epoch 6456 / 10000 Done
# train epoch 6457 / 10000 Done
# train epoch 6458 / 10000 Done
# train epoch 6459 / 10000 Done
# train epoch 6460 / 10000 Done
# dev acc 0.62902087
# train loss 0.70392483
# train epoch 6461 / 10000 Done
# train epoch 6462 / 10000 Done
# train epoch 6463 / 10000 Done
# train epoch 6464 / 10000 Done
# train epoch 6465 / 10000 Done
# dev acc 0.62786746
# train loss 0.7053251
# train epoch 6466 / 10000 Done
# train epoch 6467 / 10000 Done
# train epoch 6468 / 10000 Done
# train epoch 6469 / 10000 Done
# train epoch 6470 / 10000 Done
# dev acc 0.6284442
# train loss 0.7042217
# train epoch 6471 / 10000 Done
# train epoch 6472 / 10000 Done
# train epoch 6473 / 10000 Done
# train epoch 6474 / 10000 Done
# train epoch 6475 / 10000 Done
# dev acc 0.62799567
# train loss 0.70322376
# train epoch 6476 / 10000 Done
# train epoch 6477 / 10000 Done
# train epoch 6478 / 10000 Done
# train epoch 6479 / 10000 Done
# train epoch 6480 / 10000 Done
# dev acc 0.62783545
# train loss 0.702751
# train epoch 6481 / 10000 Done
# train epoch 6482 / 10000 Done
# train epoch 6483 / 10000 Done
# train epoch 6484 / 10000 Done
# train epoch 6485 / 10000 Done
# dev acc 0.62946945
# train loss 0.7030896
# train epoch 6486 / 10000 Done
# train epoch 6487 / 10000 Done
# train epoch 6488 / 10000 Done
# train epoch 6489 / 10000 Done
# train epoch 6490 / 10000 Done
# dev acc 0.6284121
# train loss 0.70668167
# train epoch 6491 / 10000 Done
# train epoch 6492 / 10000 Done
# train epoch 6493 / 10000 Done
# train epoch 6494 / 10000 Done
# train epoch 6495 / 10000 Done
# dev acc 0.62799567
# train loss 0.70500714
# train epoch 6496 / 10000 Done
# train epoch 6497 / 10000 Done
# train epoch 6498 / 10000 Done
# train epoch 6499 / 10000 Done
# train epoch 6500 / 10000 Done
# dev acc 0.62905294
# train loss 0.70326596
# train epoch 6501 / 10000 Done
# train epoch 6502 / 10000 Done
# train epoch 6503 / 10000 Done
# train epoch 6504 / 10000 Done
# train epoch 6505 / 10000 Done
# dev acc 0.6278034
# train loss 0.7046385
# train epoch 6506 / 10000 Done
# train epoch 6507 / 10000 Done
# train epoch 6508 / 10000 Done
# train epoch 6509 / 10000 Done
# train epoch 6510 / 10000 Done
# dev acc 0.6292131
# train loss 0.70434386
# train epoch 6511 / 10000 Done
# train epoch 6512 / 10000 Done
# train epoch 6513 / 10000 Done
# train epoch 6514 / 10000 Done
# train epoch 6515 / 10000 Done
# dev acc 0.62693834
# train loss 0.70285827
# train epoch 6516 / 10000 Done
# train epoch 6517 / 10000 Done
# train epoch 6518 / 10000 Done
# train epoch 6519 / 10000 Done
# train epoch 6520 / 10000 Done
# dev acc 0.6277073
# train loss 0.7052803
# train epoch 6521 / 10000 Done
# train epoch 6522 / 10000 Done
# train epoch 6523 / 10000 Done
# train epoch 6524 / 10000 Done
# train epoch 6525 / 10000 Done
# dev acc 0.6284442
# train loss 0.70427305
# train epoch 6526 / 10000 Done
# train epoch 6527 / 10000 Done
# train epoch 6528 / 10000 Done
# train epoch 6529 / 10000 Done
# train epoch 6530 / 10000 Done
# dev acc 0.62761116
# train loss 0.7057634
# train epoch 6531 / 10000 Done
# train epoch 6532 / 10000 Done
# train epoch 6533 / 10000 Done
# train epoch 6534 / 10000 Done
# train epoch 6535 / 10000 Done
# dev acc 0.62783545
# train loss 0.70362264
# train epoch 6536 / 10000 Done
# train epoch 6537 / 10000 Done
# train epoch 6538 / 10000 Done
# train epoch 6539 / 10000 Done
# train epoch 6540 / 10000 Done
# dev acc 0.6286044
# train loss 0.70440054
# train epoch 6541 / 10000 Done
# train epoch 6542 / 10000 Done
# train epoch 6543 / 10000 Done
# train epoch 6544 / 10000 Done
# train epoch 6545 / 10000 Done
# dev acc 0.6287005
# train loss 0.7038106
# train epoch 6546 / 10000 Done
# train epoch 6547 / 10000 Done
# train epoch 6548 / 10000 Done
# train epoch 6549 / 10000 Done
# train epoch 6550 / 10000 Done
# dev acc 0.6285403
# train loss 0.70416874
# train epoch 6551 / 10000 Done
# train epoch 6552 / 10000 Done
# train epoch 6553 / 10000 Done
# train epoch 6554 / 10000 Done
# train epoch 6555 / 10000 Done
# dev acc 0.6275471
# train loss 0.7049652
# train epoch 6556 / 10000 Done
# train epoch 6557 / 10000 Done
# train epoch 6558 / 10000 Done
# train epoch 6559 / 10000 Done
# train epoch 6560 / 10000 Done
# dev acc 0.6286044
# train loss 0.7032338
# train epoch 6561 / 10000 Done
# train epoch 6562 / 10000 Done
# train epoch 6563 / 10000 Done
# train epoch 6564 / 10000 Done
# train epoch 6565 / 10000 Done
# dev acc 0.6276432
# train loss 0.7046104
# train epoch 6566 / 10000 Done
# train epoch 6567 / 10000 Done
# train epoch 6568 / 10000 Done
# train epoch 6569 / 10000 Done
# train epoch 6570 / 10000 Done
# dev acc 0.6270665
# train loss 0.7042917
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d36ba792a63e> in <module>
#     163 m.build()
#     164 m.fit(train_x, train_y, dev_x, dev_y)
# --> 165 m.train()
#
# <ipython-input-5-d36ba792a63e> in train(self)
#     147                         self.dropout_keep_prob : self.drop_out_prob
#     148                     }
# --> 149                     sess.run(self.train_step, feed_dict = feed_dict)
#     150                     step = epoch * n_batches + batch_index
#     151                 print('train epoch %d / %d Done' % (epoch, self.n_epochs))
#
# ~/anaconda3/envs/gpu-tf/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/gpu-tf/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~/anaconda3/envs/gpu-tf/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/gpu-tf/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/gpu-tf/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/envs/gpu-tf/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
