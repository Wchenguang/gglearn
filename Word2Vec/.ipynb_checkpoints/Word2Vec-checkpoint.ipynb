# %%
import jieba
import re

def jieba_cut(_str):
    return ' '.join(jieba.lcut(_str))
def cnword_and_letter(_str):
    '''
    func: 文本清理，保留字符串中中文以及字母
    param: _str
        type: str
        detail
    return cleaned_str
        type: str
        detail: 经过strip去空格
    '''
    return "".join(re.findall("[\u4e00-\u9fa5a-zA-Z]", _str)).strip()

# %%
import pandas as pd

data_path = "./"

data = pd.read_csv(data_path + "train.csv")
data["question1"] = data["question1"].apply(cnword_and_letter)
data["question1"] = data["question1"].apply(jieba_cut)
data["question2"] = data["question2"].apply(cnword_and_letter)
data["question2"] = data["question2"].apply(jieba_cut)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.628 seconds.
# Prefix dict has been built succesfully.

# %%
import gensim
import numpy as np



def get_w2v(splited_corpus, w2v_size, min_count):
    '''
    func: 获取word2vec模型
    param: splited_corpus
        type: pd.Series
        detail: 应当为训练集中所有语料
    param: w2v_size
        type: int
        detail: w2v向量维度
    return: w2v_model
        type: gensim.models.Word2Vec
        detail: 训练的模型只可以使用其transform接口
    '''
    sentences = [x.split() for x in splited_corpus]
    model = gensim.models.Word2Vec(sentences, min_count=min_count, size=w2v_size)
    return model

def get_w2v_key_vev(w2v_model):
    vecs = []
    words = []
    for word in w2v_model.wv.vocab:
        vecs.append(w2v_model[word])
        words.append(word)
    return words, vecs

def get_x_index(x, words):
    res = []
    for inst in x:
        res.append(np.array([words.index(word) for word in inst.split() if word in words]))
    return res

def mean_len(list_2d):
    meanlen = 0
    for arr in list_2d:
        meanlen += len(arr)
    return meanlen / len(list_2d)

def ceil2(num):
    res = 2
    while res < num:
        res *= 2
    return res

def padding(data2d, max_len, pad_val):
    res = []
    for index, seq in enumerate(data2d):
        if(len(seq) < max_len):
            res.append(np.concatenate([seq, np.full([max_len - len(seq)], pad_val)]))
        else:
            res.append(seq[:max_len])
    return res

def concat_list_h(list1, list2):
    res = []
    for i, ele in enumerate(list1):
        res.append(np.concatenate([ele, list2[i]]))
    return res



corpus = list(data['question1']) + list(data['question2'])

w2v_model = get_w2v(corpus[0:20000], 300, min_count = 1)

# %%
w2v_model.wv.vocab
# Out:
# {'艾滋病': <gensim.models.keyedvectors.Vocab at 0x7f806a6c37b8>,
#  '窗口期': <gensim.models.keyedvectors.Vocab at 0x7f7f29db15c0>,
#  '会': <gensim.models.keyedvectors.Vocab at 0x7f7f299e6ba8>,
#  '出现': <gensim.models.keyedvectors.Vocab at 0x7f7f299e6be0>,
#  '腹泻': <gensim.models.keyedvectors.Vocab at 0x7f7f299e6c18>,
#  '症状': <gensim.models.keyedvectors.Vocab at 0x7f7f299e6c50>,
#  '吗': <gensim.models.keyedvectors.Vocab at 0x7f7f299e6c88>,
#  '由于': <gensim.models.keyedvectors.Vocab at 0x7f7f299e6cc0>,
#  '糖尿病': <gensim.models.keyedvectors.Vocab at 0x7f7f299e6cf8>,
#  '引起': <gensim.models.keyedvectors.Vocab at 0x7f7f299e6d30>,
#  '末梢神经': <gensim.models.keyedvectors.Vocab at 0x7f7f299e6d68>,
#  '炎': <gensim.models.keyedvectors.Vocab at 0x7f7f299e6da0>,
#  '怎么': <gensim.models.keyedvectors.Vocab at 0x7f7f299e6dd8>,
#  '根治': <gensim.models.keyedvectors.Vocab at 0x7f7f299e6e10>,
#  'H': <gensim.models.keyedvectors.Vocab at 0x7f7f299e6e48>,
#  '型': <gensim.models.keyedvectors.Vocab at 0x7f7f299e6e80>,
#  '高血压': <gensim.models.keyedvectors.Vocab at 0x7f7f299e6eb8>,
#  '是': <gensim.models.keyedvectors.Vocab at 0x7f7f299e6ef0>,
#  '通': <gensim.models.keyedvectors.Vocab at 0x7f7f299e6f28>,
#  '所说': <gensim.models.keyedvectors.Vocab at 0x7f7f299e6f60>,
#  '的': <gensim.models.keyedvectors.Vocab at 0x7f7f299e6f98>,
#  '高血脂': <gensim.models.keyedvectors.Vocab at 0x7f7f299e6fd0>,
#  '跟': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16048>,
#  '尿毒症': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16080>,
#  '有': <gensim.models.keyedvectors.Vocab at 0x7f7f29b160b8>,
#  '什么': <gensim.models.keyedvectors.Vocab at 0x7f7f29b160f0>,
#  '区别': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16128>,
#  '你好': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16160>,
#  '我岁': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16198>,
#  '患': <gensim.models.keyedvectors.Vocab at 0x7f7f29b161d0>,
#  '爱喝': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16208>,
#  '酸奶': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16240>,
#  '可以': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16278>,
#  '能否': <gensim.models.keyedvectors.Vocab at 0x7f7f29b162b0>,
#  '吃': <gensim.models.keyedvectors.Vocab at 0x7f7f29b162e8>,
#  '减肥药': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16320>,
#  '怎样': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16358>,
#  '阻断': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16390>,
#  '乙肝': <gensim.models.keyedvectors.Vocab at 0x7f7f29b163c8>,
#  '传播': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16400>,
#  '途径': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16438>,
#  '糖耐量': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16470>,
#  '高': <gensim.models.keyedvectors.Vocab at 0x7f7f29b164a8>,
#  '一定': <gensim.models.keyedvectors.Vocab at 0x7f7f29b164e0>,
#  '明显': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16518>,
#  '大三阳': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16550>,
#  '脾稍': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16588>,
#  '大现': <gensim.models.keyedvectors.Vocab at 0x7f7f29b165c0>,
#  '腹胀': <gensim.models.keyedvectors.Vocab at 0x7f7f29b165f8>,
#  '怎么办': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16630>,
#  '壮阳药': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16668>,
#  '对': <gensim.models.keyedvectors.Vocab at 0x7f7f29b166a0>,
#  '影响': <gensim.models.keyedvectors.Vocab at 0x7f7f29b166d8>,
#  '能': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16710>,
#  '愈': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16748>,
#  '表面抗原': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16780>,
#  '阳性': <gensim.models.keyedvectors.Vocab at 0x7f7f29b167b8>,
#  '已': <gensim.models.keyedvectors.Vocab at 0x7f7f29b167f0>,
#  '感染': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16828>,
#  '了': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16860>,
#  '九年': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16898>,
#  '应该': <gensim.models.keyedvectors.Vocab at 0x7f7f29b168d0>,
#  '中药': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16908>,
#  '好': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16940>,
#  '这样': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16978>,
#  '算是': <gensim.models.keyedvectors.Vocab at 0x7f7f29b169b0>,
#  '孕期': <gensim.models.keyedvectors.Vocab at 0x7f7f29b169e8>,
#  '大量': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16a20>,
#  '出汗': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16a58>,
#  '怎么回事': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16a90>,
#  '糖尿病人': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16ac8>,
#  '做': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16b00>,
#  '胰岛': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16b38>,
#  '修复': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16b70>,
#  '术': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16ba8>,
#  '能治好': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16be0>,
#  '寿命': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16c18>,
#  '治疗费': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16c50>,
#  '大概': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16c88>,
#  '多少': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16cc0>,
#  '人': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16cf8>,
#  '常常': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16d30>,
#  '很': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16d68>,
#  '乏力': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16da0>,
#  '该': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16dd8>,
#  '者': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16e10>,
#  '平时': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16e48>,
#  '如何': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16e80>,
#  '测': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16eb8>,
#  '血糖': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16ef0>,
#  '脑梗塞': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16f28>,
#  '是否': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16f60>,
#  '遗传': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16f98>,
#  '哪些': <gensim.models.keyedvectors.Vocab at 0x7f7f29b16fd0>,
#  '乳腺癌': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a048>,
#  '转移': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a080>,
#  '到': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a0b8>,
#  '肺部': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a0f0>,
#  '箭叶': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a128>,
#  '秋葵': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a160>,
#  '治疗': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a198>,
#  '最新': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a1d0>,
#  '方法': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a208>,
#  '每天': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a240>,
#  '红枣': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a278>,
#  '乙肝病毒': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a2b0>,
#  '携带者': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a2e8>,
#  '又': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a320>,
#  '病人': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a358>,
#  '男性': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a390>,
#  '得': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a3c8>,
#  '二型': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a400>,
#  '生育': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a438>,
#  '性': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a470>,
#  '脑出血': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a4a8>,
#  '用': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a4e0>,
#  '人用': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a518>,
#  '过': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a550>,
#  '自慰器': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a588>,
#  '成人': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a5c0>,
#  '玩具': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a5f8>,
#  '被': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a630>,
#  '传染': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a668>,
#  '喝': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a6a0>,
#  '蜂王浆': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a6d8>,
#  '么': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a710>,
#  '表面': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a748>,
#  '抗体': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a780>,
#  'e': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a7b8>,
#  '病': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a7f0>,
#  '两个': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a828>,
#  '都': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a860>,
#  '没有': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a898>,
#  '肛交': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a8d0>,
#  '没戴': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a908>,
#  '安全套': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a940>,
#  '心脏病': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a978>,
#  '意思': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a9b0>,
#  '办': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1a9e8>,
#  '食品': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1aa20>,
#  '健康证': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1aa58>,
#  '老年人': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1aa90>,
#  '危象': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1aac8>,
#  '定义': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1ab00>,
#  '我': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1ab38>,
#  '想': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1ab70>,
#  '问问': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1aba8>,
#  '治疗仪': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1abe0>,
#  '治': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1ac18>,
#  '管用': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1ac50>,
#  '吃糖': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1ac88>,
#  '多能': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1acc0>,
#  '肝': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1acf8>,
#  '主食': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1ad30>,
#  '老公': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1ad68>,
#  '血脂': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1ada0>,
#  '稠': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1add8>,
#  '一直': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1ae10>,
#  '在': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1ae48>,
#  '吃药': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1ae80>,
#  '老婆': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1aeb8>,
#  '怀孕': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1aef0>,
#  '胎儿': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1af28>,
#  '啥': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1af60>,
#  '茶': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1af98>,
#  '比较': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1afd0>,
#  '前期': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f048>,
#  '酮': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f080>,
#  '中毒': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f0b8>,
#  '检测': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f0f0>,
#  '呈': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f128>,
#  '腿': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f160>,
#  '疼痛': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f198>,
#  '难忍': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f1d0>,
#  '口交': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f208>,
#  '可能性': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f240>,
#  '大': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f278>,
#  '尿频': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f2b0>,
#  '尿急': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f2e8>,
#  '药': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f320>,
#  '鸡蛋': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f358>,
#  '才': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f390>,
#  '健康': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f3c8>,
#  '脑': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f400>,
#  '先': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f438>,
#  '放疗': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f470>,
#  '还是': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f4a8>,
#  '化疗': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f4e0>,
#  '骨转移': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f518>,
#  '肾病': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f550>,
#  '生活': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f588>,
#  '方式': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f5c0>,
#  '禁忌': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f5f8>,
#  '带套': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f630>,
#  '不带': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f668>,
#  '套': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f6a0>,
#  '性交': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f6d8>,
#  '做爱': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f710>,
#  '几率': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f748>,
#  '分别': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f780>,
#  '多大': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f7b8>,
#  '手脚': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f7f0>,
#  '发麻': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f828>,
#  '中医': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f860>,
#  '特效药': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f898>,
#  '调理': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f8d0>,
#  '患者': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f908>,
#  '晚饭': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f940>,
#  '后': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f978>,
#  '一个': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f9b0>,
#  '小时': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1f9e8>,
#  '去': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fa20>,
#  '慢跑': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fa58>,
#  '身体': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fa90>,
#  '好处': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fac8>,
#  '检查': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fb00>,
#  '自己': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fb38>,
#  '有没有': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fb70>,
#  '挂': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fba8>,
#  '科': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fbe0>,
#  '打': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fc18>,
#  '葡萄糖': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fc50>,
#  '乳房': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fc88>,
#  '妊娠': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fcc0>,
#  '综合征': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fcf8>,
#  '护理': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fd30>,
#  '通过': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fd68>,
#  '晚期': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fda0>,
#  '运动': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fdd8>,
#  '控制': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fe10>,
#  '补钙': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fe48>,
#  '医生': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fe80>,
#  '肾阴虚': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1feb8>,
#  '胃': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1fef0>,
#  '火旺': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1ff28>,
#  '有时': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1ff60>,
#  '耳鸣': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1ff98>,
#  '脾虚': <gensim.models.keyedvectors.Vocab at 0x7f7f29b1ffd0>,
#  '脸色': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20048>,
#  '黄': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20080>,
#  '请问': <gensim.models.keyedvectors.Vocab at 0x7f7f29b200b8>,
#  '推荐': <gensim.models.keyedvectors.Vocab at 0x7f7f29b200f0>,
#  '一方': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20128>,
#  '不胜': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20160>,
#  '感谢': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20198>,
#  '营养品': <gensim.models.keyedvectors.Vocab at 0x7f7f29b201d0>,
#  '阴道炎': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20208>,
#  '复发': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20240>,
#  '和': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20278>,
#  '直接': <gensim.models.keyedvectors.Vocab at 0x7f7f29b202b0>,
#  '关系': <gensim.models.keyedvectors.Vocab at 0x7f7f29b202e8>,
#  '打针': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20320>,
#  '桂圆': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20358>,
#  '甲减': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20390>,
#  '经常': <gensim.models.keyedvectors.Vocab at 0x7f7f29b203c8>,
#  '失眠': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20400>,
#  '喝咖啡': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20438>,
#  '若能': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20470>,
#  '抽烟': <gensim.models.keyedvectors.Vocab at 0x7f7f29b204a8>,
#  '试验': <gensim.models.keyedvectors.Vocab at 0x7f7f29b204e0>,
#  '抽血': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20518>,
#  '时间': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20550>,
#  '算': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20588>,
#  '注射': <gensim.models.keyedvectors.Vocab at 0x7f7f29b205c0>,
#  '胰岛素': <gensim.models.keyedvectors.Vocab at 0x7f7f29b205f8>,
#  '过敏': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20630>,
#  '换': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20668>,
#  '早上': <gensim.models.keyedvectors.Vocab at 0x7f7f29b206a0>,
#  '喝牛奶': <gensim.models.keyedvectors.Vocab at 0x7f7f29b206d8>,
#  '尿蛋白': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20710>,
#  '这个': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20748>,
#  '情况': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20780>,
#  '乙肝疫苗': <gensim.models.keyedvectors.Vocab at 0x7f7f29b207b8>,
#  '无套': <gensim.models.keyedvectors.Vocab at 0x7f7f29b207f0>,
#  '口': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20828>,
#  '交会': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20860>,
#  'hiv': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20898>,
#  '婴儿': <gensim.models.keyedvectors.Vocab at 0x7f7f29b208d0>,
#  '黄疸': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20908>,
#  '偏高': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20940>,
#  '不能': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20978>,
#  '种': <gensim.models.keyedvectors.Vocab at 0x7f7f29b209b0>,
#  '山药': <gensim.models.keyedvectors.Vocab at 0x7f7f29b209e8>,
#  '偏方': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20a20>,
#  '能治': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20a58>,
#  '性生活': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20a90>,
#  '妊娠期': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20ac8>,
#  '饮食': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20b00>,
#  '要': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20b38>,
#  '注意': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20b70>,
#  '呢': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20ba8>,
#  '岁': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20be0>,
#  '孕妇': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20c18>,
#  '发现': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20c50>,
#  '新药': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20c88>,
#  '神经病': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20cc0>,
#  '变': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20cf8>,
#  '找': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20d30>,
#  '科室': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20d68>,
#  '艾滋': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20da0>,
#  '便秘': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20dd8>,
#  '防治': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20e10>,
#  '多久': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20e48>,
#  '吃些': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20e80>,
#  '高血糖': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20eb8>,
#  '降糖药': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20ef0>,
#  '更年期': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20f28>,
#  '有个': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20f60>,
#  '同学': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20f98>,
#  '熊胆': <gensim.models.keyedvectors.Vocab at 0x7f7f29b20fd0>,
#  '粉': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25048>,
#  '灵芝': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25080>,
#  '糖尿病足': <gensim.models.keyedvectors.Vocab at 0x7f7f29b250b8>,
#  '泡脚': <gensim.models.keyedvectors.Vocab at 0x7f7f29b250f0>,
#  '应': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25128>,
#  '进行': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25160>,
#  '才能': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25198>,
#  '预防': <gensim.models.keyedvectors.Vocab at 0x7f7f29b251d0>,
#  '眼部': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25208>,
#  '并发症': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25240>,
#  '发生': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25278>,
#  '一型': <gensim.models.keyedvectors.Vocab at 0x7f7f29b252b0>,
#  '生': <gensim.models.keyedvectors.Vocab at 0x7f7f29b252e8>,
#  '孩子': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25320>,
#  '快速': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25358>,
#  '消除': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25390>,
#  '尿糖': <gensim.models.keyedvectors.Vocab at 0x7f7f29b253c8>,
#  '个': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25400>,
#  '加号': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25438>,
#  '重度': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25470>,
#  '什么样': <gensim.models.keyedvectors.Vocab at 0x7f7f29b254a8>,
#  '呕吐': <gensim.models.keyedvectors.Vocab at 0x7f7f29b254e0>,
#  '现象': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25518>,
#  '服药': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25550>,
#  '进口': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25588>,
#  '国产': <gensim.models.keyedvectors.Vocab at 0x7f7f29b255c0>,
#  '动': <gensim.models.keyedvectors.Vocab at 0x7f7f29b255f8>,
#  '手术': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25630>,
#  '活多久': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25668>,
#  '公共': <gensim.models.keyedvectors.Vocab at 0x7f7f29b256a0>,
#  '浴室': <gensim.models.keyedvectors.Vocab at 0x7f7f29b256d8>,
#  '洗': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25710>,
#  '淋浴': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25748>,
#  '代表': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25780>,
#  '慢性': <gensim.models.keyedvectors.Vocab at 0x7f7f29b257b8>,
#  '乳腺': <gensim.models.keyedvectors.Vocab at 0x7f7f29b257f0>,
#  '增生': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25828>,
#  '扩散': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25860>,
#  '还': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25898>,
#  '早期': <gensim.models.keyedvectors.Vocab at 0x7f7f29b258d0>,
#  '不适': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25908>,
#  '可能': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25940>,
#  '精液': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25978>,
#  '阴道': <gensim.models.keyedvectors.Vocab at 0x7f7f29b259b0>,
#  '分泌物': <gensim.models.keyedvectors.Vocab at 0x7f7f29b259e8>,
#  '玉米': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25a20>,
#  '口渴': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25a58>,
#  '危害': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25a90>,
#  '人群': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25ac8>,
#  '白内障': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25b00>,
#  '三七': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25b38>,
#  '用药': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25b70>,
#  '新生儿': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25ba8>,
#  '接种': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25be0>,
#  '免疫': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25c18>,
#  '球蛋白': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25c50>,
#  '五项': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25c88>,
#  '指标': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25cc0>,
#  '解读': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25cf8>,
#  '乙型肝炎': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25d30>,
#  '抗原': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25d68>,
#  '血症': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25da0>,
#  '走': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25dd8>,
#  '医保': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25e10>,
#  'jiao': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25e48>,
#  '周': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25e80>,
#  '查出': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25eb8>,
#  '哈': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25ef0>,
#  '上': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25f28>,
#  '夜班': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25f60>,
#  '选用': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25f98>,
#  '物': <gensim.models.keyedvectors.Vocab at 0x7f7f29b25fd0>,
#  '干扰素': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34048>,
#  '治愈': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34080>,
#  '使运': <gensim.models.keyedvectors.Vocab at 0x7f7f29b340b8>,
#  '抗生素': <gensim.models.keyedvectors.Vocab at 0x7f7f29b340f0>,
#  '梨': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34128>,
#  '打过': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34160>,
#  '没': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34198>,
#  '不用': <gensim.models.keyedvectors.Vocab at 0x7f7f29b341d0>,
#  '再': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34208>,
#  '需要': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34240>,
#  '几针': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34278>,
#  '哪个': <gensim.models.keyedvectors.Vocab at 0x7f7f29b342b0>,
#  '由': <gensim.models.keyedvectors.Vocab at 0x7f7f29b342e8>,
#  '大腿': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34320>,
#  '根部': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34358>,
#  '溃烂': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34390>,
#  '降血糖': <gensim.models.keyedvectors.Vocab at 0x7f7f29b343c8>,
#  '淋巴': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34400>,
#  '高脂肪': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34438>,
#  '人员': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34470>,
#  '降压药': <gensim.models.keyedvectors.Vocab at 0x7f7f29b344a8>,
#  '三甲': <gensim.models.keyedvectors.Vocab at 0x7f7f29b344e0>,
#  '医院': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34518>,
#  '准确': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34550>,
#  '血压': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34588>,
#  '不': <gensim.models.keyedvectors.Vocab at 0x7f7f29b345c0>,
#  '稳定': <gensim.models.keyedvectors.Vocab at 0x7f7f29b345f8>,
#  '乙肝患者': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34630>,
#  '项目': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34668>,
#  '全': <gensim.models.keyedvectors.Vocab at 0x7f7f29b346a0>,
#  '方面': <gensim.models.keyedvectors.Vocab at 0x7f7f29b346d8>,
#  '吃海鲜': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34710>,
#  '肾性': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34748>,
#  '效果': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34780>,
#  '担心': <gensim.models.keyedvectors.Vocab at 0x7f7f29b347b8>,
#  '不会': <gensim.models.keyedvectors.Vocab at 0x7f7f29b347f0>,
#  '发病': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34828>,
#  '原因': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34860>,
#  '眼看': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34898>,
#  '不见': <gensim.models.keyedvectors.Vocab at 0x7f7f29b348d0>,
#  '术后': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34908>,
#  '冷汗': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34940>,
#  '买': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34978>,
#  '血糖仪': <gensim.models.keyedvectors.Vocab at 0x7f7f29b349b0>,
#  '玉米面': <gensim.models.keyedvectors.Vocab at 0x7f7f29b349e8>,
#  '馒头': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34a20>,
#  '晚间': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34a58>,
#  '出冷汗': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34a90>,
#  '糖': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34ac8>,
#  '筛': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34b00>,
#  'ogtt': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34b38>,
#  '糖耐有': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34b70>,
#  '不同': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34ba8>,
#  '最近': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34be0>,
#  '脚': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34c18>,
#  '浮肿': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34c50>,
#  '长豆': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34c88>,
#  '内分泌': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34cc0>,
#  '现在': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34cf8>,
#  '急性': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34d30>,
#  '恢复期': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34d68>,
#  '这': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34da0>,
#  '方案': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34dd8>,
#  '严重': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34e10>,
#  '血糖高': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34e48>,
#  '下来': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34e80>,
#  '呀': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34eb8>,
#  '转阴': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34ef0>,
#  '好了吗': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34f28>,
#  '复诊': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34f60>,
#  '观察': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34f98>,
#  '初期': <gensim.models.keyedvectors.Vocab at 0x7f7f29b34fd0>,
#  '副作用': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36048>,
#  '输注': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36080>,
#  '溶液': <gensim.models.keyedvectors.Vocab at 0x7f7f29b360b8>,
#  '患有': <gensim.models.keyedvectors.Vocab at 0x7f7f29b360f0>,
#  '目前': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36128>,
#  '已有': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36160>,
#  '一年': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36198>,
#  '多': <gensim.models.keyedvectors.Vocab at 0x7f7f29b361d0>,
#  '服用': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36208>,
#  '两种': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36240>,
#  '改成': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36278>,
#  '一种': <gensim.models.keyedvectors.Vocab at 0x7f7f29b362b0>,
#  '酮体': <gensim.models.keyedvectors.Vocab at 0x7f7f29b362e8>,
#  '高有': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36320>,
#  '食物': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36358>,
#  '补': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36390>,
#  '白血球': <gensim.models.keyedvectors.Vocab at 0x7f7f29b363c8>,
#  '切除': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36400>,
#  '子宫': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36438>,
#  '熬夜': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36470>,
#  '引发': <gensim.models.keyedvectors.Vocab at 0x7f7f29b364a8>,
#  '男孩': <gensim.models.keyedvectors.Vocab at 0x7f7f29b364e0>,
#  '能要': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36518>,
#  '达到': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36550>,
#  '是不是': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36588>,
#  '丈夫': <gensim.models.keyedvectors.Vocab at 0x7f7f29b365c0>,
#  '妻子': <gensim.models.keyedvectors.Vocab at 0x7f7f29b365f8>,
#  '脑血管': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36630>,
#  '堵塞': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36668>,
#  '升高': <gensim.models.keyedvectors.Vocab at 0x7f7f29b366a0>,
#  '钱': <gensim.models.keyedvectors.Vocab at 0x7f7f29b366d8>,
#  '一针': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36710>,
#  '大夫': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36748>,
#  '转氨酶': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36780>,
#  '周身': <gensim.models.keyedvectors.Vocab at 0x7f7f29b367b8>,
#  '发氧起': <gensim.models.keyedvectors.Vocab at 0x7f7f29b367f0>,
#  '疙瘩': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36828>,
#  '苹果': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36860>,
#  '冬天': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36898>,
#  '缓解': <gensim.models.keyedvectors.Vocab at 0x7f7f29b368d0>,
#  '作用': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36908>,
#  '扩张': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36940>,
#  '血管': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36978>,
#  '临床表现': <gensim.models.keyedvectors.Vocab at 0x7f7f29b369b0>,
#  '长期': <gensim.models.keyedvectors.Vocab at 0x7f7f29b369e8>,
#  '玉米须': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36a20>,
#  '水': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36a58>,
#  '啊': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36a90>,
#  '男生': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36ac8>,
#  '锻炼': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36b00>,
#  '核心': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36b38>,
#  '性功能': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36b70>,
#  '障碍': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36ba8>,
#  '办法': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36be0>,
#  '家人': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36c18>,
#  '一起': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36c50>,
#  '吃饭': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36c88>,
#  '老年': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36cc0>,
#  '大便': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36cf8>,
#  '干躁': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36d30>,
#  '尿里': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36d68>,
#  '甜味': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36da0>,
#  '为什么': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36dd8>,
#  '高中生': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36e10>,
#  '唾液': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36e48>,
#  '说话': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36e80>,
#  '打喷嚏': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36eb8>,
#  '会否': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36ef0>,
#  '产生': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36f28>,
#  '依赖性': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36f60>,
#  '尿': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36f98>,
#  '颜色': <gensim.models.keyedvectors.Vocab at 0x7f7f29b36fd0>,
#  '手淫': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c048>,
#  '自慰': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c080>,
#  '使用': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c0b8>,
#  '年轻人': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c0f0>,
#  '药好': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c128>,
#  '男': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c160>,
#  '男同性恋': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c198>,
#  '性行为': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c1d0>,
#  '怀孕期': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c208>,
#  '带': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c240>,
#  '避孕套': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c278>,
#  '就': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c2b0>,
#  '感冒': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c2e8>,
#  '黎明': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c320>,
#  '空腹': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c358>,
#  '慢病': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c390>,
#  '政策': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c3c8>,
#  '身上': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c400>,
#  '疼': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c438>,
#  '痒': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c470>,
#  '中期': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c4a8>,
#  '腿部': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c4e0>,
#  '动脉硬化': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c518>,
#  '此病': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c550>,
#  '拉肚子': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c588>,
#  '晚餐': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c5c0>,
#  '木瓜': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c5f8>,
#  '汤': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c630>,
#  '营养素': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c668>,
#  '脑部': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c6a0>,
#  '胃镜': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c6d8>,
#  '绿豆': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c710>,
#  '除了': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c748>,
#  '价格': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c780>,
#  '外': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c7b8>,
#  '还有': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c7f0>,
#  '什莫': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c828>,
#  '胰岛素泵': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c860>,
#  '安康': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c898>,
#  '哪': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c8d0>,
#  '眼底': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c908>,
#  '出血': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c940>,
#  '黄斑': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c978>,
#  '水肿': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c9b0>,
#  '父亲': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3c9e8>,
#  '子女': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3ca20>,
#  '只能': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3ca58>,
#  '那些': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3ca90>,
#  '饮料': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3cac8>,
#  '尖锐湿疣': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3cb00>,
#  '就是': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3cb38>,
#  '中国': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3cb70>,
#  '烂': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3cba8>,
#  '法治': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3cbe0>,
#  '尿检': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3cc18>,
#  '中': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3cc50>,
#  '血检': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3cc88>,
#  '各项': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3ccc0>,
#  '正常': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3ccf8>,
#  '死': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3cd30>,
#  '六项': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3cd68>,
#  '化验单': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3cda0>,
#  '看': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3cdd8>,
#  '也': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3ce10>,
#  '不是': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3ce48>,
#  '您好': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3ce80>,
#  '求问': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3ceb8>,
#  '血红蛋白': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3cef0>,
#  '菠萝': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3cf28>,
#  '第三': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3cf60>,
#  '针': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3cf98>,
#  '比': <gensim.models.keyedvectors.Vocab at 0x7f7f29b3cfd0>,
#  '预定': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f048>,
#  '甲亢': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f080>,
#  '与': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f0b8>,
#  '不吃': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f0f0>,
#  '出国': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f128>,
#  '体检': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f160>,
#  '口服液': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f198>,
#  '最': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f1d0>,
#  '简单': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f208>,
#  '肺': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f240>,
#  '救': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f278>,
#  '常年': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f2b0>,
#  '厌食': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f2e8>,
#  '坐飞机': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f320>,
#  '蛋白尿': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f358>,
#  '并': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f390>,
#  '饥饿': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f3c8>,
#  '说明': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f400>,
#  '容易': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f438>,
#  '上火': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f470>,
#  '食谱': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f4a8>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f4e0>,
#  '注意事项': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f518>,
#  '杏仁': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f550>,
#  '会渴': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f588>,
#  '冶能': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f5c0>,
#  '鉴定': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f5f8>,
#  '继发性': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f630>,
#  '原发性': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f668>,
#  '可': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f6a0>,
#  '尿液': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f6d8>,
#  '病毒': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f710>,
#  '抵抗': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f748>,
#  '诊断': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f780>,
#  '标准': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f7b8>,
#  '共同': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f7f0>,
#  '血液': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f828>,
#  '干涸': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f860>,
#  '但是': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f898>,
#  '说明书': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f8d0>,
#  '写': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f908>,
#  '腋下': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f940>,
#  '淋巴结': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f978>,
#  '肿大': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f9b0>,
#  '伤口': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7f9e8>,
#  '接触': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fa20>,
#  '不洁': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fa58>,
#  '行为': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fa90>,
#  '为': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fac8>,
#  '紧张': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fb00>,
#  '如果': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fb38>,
#  '口腔': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fb70>,
#  '溃疡': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fba8>,
#  '接吻': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fbe0>,
#  '眼睛': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fc18>,
#  '低血糖': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fc50>,
#  '些': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fc88>,
#  '最合适': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fcc0>,
#  '铁皮': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fcf8>,
#  '石斛': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fd30>,
#  '胖': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fd68>,
#  '输': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fda0>,
#  '月经': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fdd8>,
#  '疙瘩汤': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fe10>,
#  '期间': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fe48>,
#  '全身': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fe80>,
#  '无力': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7feb8>,
#  '红酒': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7fef0>,
#  '单纯': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7ff28>,
#  '轻微': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7ff60>,
#  '脑梗': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7ff98>,
#  '北京': <gensim.models.keyedvectors.Vocab at 0x7f7f29a7ffd0>,
#  '哪家': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87048>,
#  '运动会': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87080>,
#  '给': <gensim.models.keyedvectors.Vocab at 0x7f7f29a870b8>,
#  '带来': <gensim.models.keyedvectors.Vocab at 0x7f7f29a870f0>,
#  '夫妻': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87128>,
#  '为何': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87160>,
#  '增高': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87198>,
#  '心肌': <gensim.models.keyedvectors.Vocab at 0x7f7f29a871d0>,
#  '肥厚': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87208>,
#  '费用': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87240>,
#  '视网膜': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87278>,
#  '病变': <gensim.models.keyedvectors.Vocab at 0x7f7f29a872b0>,
#  '单位': <gensim.models.keyedvectors.Vocab at 0x7f7f29a872e8>,
#  '早晨': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87320>,
#  '餐前': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87358>,
#  '生化': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87390>,
#  '肺癌': <gensim.models.keyedvectors.Vocab at 0x7f7f29a873c8>,
#  '小腿': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87400>,
#  '肿': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87438>,
#  '皮肤病': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87470>,
#  '第一': <gensim.models.keyedvectors.Vocab at 0x7f7f29a874a8>,
#  '第二': <gensim.models.keyedvectors.Vocab at 0x7f7f29a874e0>,
#  '间隔': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87518>,
#  '谢谢': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87550>,
#  'c': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87588>,
#  '肽值': <gensim.models.keyedvectors.Vocab at 0x7f7f29a875c0>,
#  '宜喝': <gensim.models.keyedvectors.Vocab at 0x7f7f29a875f8>,
#  '下': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87630>,
#  '疾病': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87668>,
#  '导致': <gensim.models.keyedvectors.Vocab at 0x7f7f29a876a0>,
#  '怎样治': <gensim.models.keyedvectors.Vocab at 0x7f7f29a876d8>,
#  '肿瘤': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87710>,
#  '标志物': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87748>,
#  '危险': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87780>,
#  '疫苗': <gensim.models.keyedvectors.Vocab at 0x7f7f29a877b8>,
#  '瘙痒': <gensim.models.keyedvectors.Vocab at 0x7f7f29a877f0>,
#  '完': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87828>,
#  '高是': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87860>,
#  '号': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87898>,
#  '如虾': <gensim.models.keyedvectors.Vocab at 0x7f7f29a878d0>,
#  '蟹': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87908>,
#  '昏迷': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87940>,
#  '补血': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87978>,
#  '试管婴儿': <gensim.models.keyedvectors.Vocab at 0x7f7f29a879b0>,
#  '及': <gensim.models.keyedvectors.Vocab at 0x7f7f29a879e8>,
#  '人工授精': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87a20>,
#  '只': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87a58>,
#  '豆渣': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87a90>,
#  '区分': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87ac8>,
#  '梅毒': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87b00>,
#  '联系': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87b38>,
#  '胸闷': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87b70>,
#  '头晕': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87ba8>,
#  '耐药': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87be0>,
#  '产妇': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87c18>,
#  '乌鸡汤': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87c50>,
#  '恶性肿瘤': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87c88>,
#  '几天': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87cc0>,
#  '痛': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87cf8>,
#  '嘴巴': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87d30>,
#  '有点': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87d68>,
#  '歪': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87da0>,
#  '怎': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87dd8>,
#  '回事': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87e10>,
#  '吃果': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87e48>,
#  '导片': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87e80>,
#  '血': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87eb8>,
#  '禟': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87ef0>,
#  '饭后': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87f28>,
#  '超标': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87f60>,
#  '选药': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87f98>,
#  '免疫力': <gensim.models.keyedvectors.Vocab at 0x7f7f29a87fd0>,
#  '低下': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c048>,
#  '何在': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c080>,
#  '丙干': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c0b8>,
#  '而且': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c0f0>,
#  '好像': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c128>,
#  '不太好': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c160>,
#  '葡萄酒': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c198>,
#  '低血压': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c1d0>,
#  '伴有': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c208>,
#  '头疼': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c240>,
#  '九个': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c278>,
#  '月': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c2b0>,
#  '发烧': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c2e8>,
#  '薏米': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c320>,
#  '红豆': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c358>,
#  '粥': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c390>,
#  '刚': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c3c8>,
#  '总好': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c400>,
#  '不了': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c438>,
#  '济南': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c470>,
#  '脑供': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c4a8>,
#  '不足': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c4e0>,
#  '同时': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c518>,
#  '最好': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c550>,
#  '多年': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c588>,
#  '贫血': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c5c0>,
#  '潜伏期': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c5f8>,
#  '抗病毒': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c630>,
#  '吐血': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c668>,
#  '羊肉': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c6a0>,
#  '牛肉': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c6d8>,
#  '两对半': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c710>,
#  '肝功能': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c748>,
#  '排骨汤': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c780>,
#  '常': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c7b8>,
#  '属': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c7f0>,
#  '餐后': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c828>,
#  '有效': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c860>,
#  '人工受孕': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c898>,
#  '避免': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c8d0>,
#  '瓜子': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c908>,
#  '粉对': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c940>,
#  '脑血栓': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c978>,
#  '有害': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c9b0>,
#  '嘛': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8c9e8>,
#  '几年': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8ca20>,
#  '发病率': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8ca58>,
#  '逐年': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8ca90>,
#  '提高': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8cac8>,
#  '不佳': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8cb00>,
#  '皮肤': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8cb38>,
#  '有小红': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8cb70>,
#  '硬块': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8cba8>,
#  '痛风': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8cbe0>,
#  '日常': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8cc18>,
#  '必要': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8cc50>,
#  '卵巢': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8cc88>,
#  '打甲流': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8ccc0>,
#  '属于': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8ccf8>,
#  '橙子': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8cd30>,
#  '前后': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8cd68>,
#  '做些': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8cda0>,
#  '切片': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8cdd8>,
#  '西红柿': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8ce10>,
#  '面': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8ce48>,
#  '止咳': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8ce80>,
#  '糖浆': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8ceb8>,
#  '掉头发': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8cef0>,
#  '合并': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8cf28>,
#  '问': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8cf60>,
#  '一下': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8cf98>,
#  '视力': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8cfd0>,
#  '模糊': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f048>,
#  '一天': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f080>,
#  '几个': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f0b8>,
#  '儿童': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f0f0>,
#  'mmol': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f128>,
#  '近来': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f160>,
#  '二甲': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f198>,
#  '双': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f1d0>,
#  '胍': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f208>,
#  '高降': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f240>,
#  '跑步': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f278>,
#  '低烧': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f2b0>,
#  '干细胞': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f2e8>,
#  '移植': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f320>,
#  '冰糖': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f358>,
#  '银耳': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f390>,
#  '大米饭': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f3c8>,
#  '还会': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f400>,
#  '汗液': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f438>,
#  '宝宝': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f470>,
#  '骨折': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f4a8>,
#  '有利于': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f4e0>,
#  '愈合': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f518>,
#  '肾阳虚': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f550>,
#  '早泄': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f588>,
#  '中成药': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f5c0>,
#  '突发性': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f5f8>,
#  '肚泻': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f630>,
#  '头痛': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f668>,
#  '有关': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f6a0>,
#  '带菌': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f6d8>,
#  '胆红素': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f710>,
#  '咋': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f748>,
#  '三多': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f780>,
#  '一少': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f7b8>,
#  '糖化': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f7f0>,
#  '下代嘛': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f828>,
#  '肿块': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f860>,
#  '胆结石': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f898>,
#  '做手术': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f8d0>,
#  '或者': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f908>,
#  '哮喘': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f940>,
#  '肺心病': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f978>,
#  '至': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f9b0>,
#  '心衰': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8f9e8>,
#  '顺产': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fa20>,
#  'HIV': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fa58>,
#  '消化道': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fa90>,
#  '嫖娼': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fac8>,
#  '艾滋病毒': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fb00>,
#  '弱阳性': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fb38>,
#  '谷丙': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fb70>,
#  '突然': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fba8>,
#  '肾结石': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fbe0>,
#  '蚊子': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fc18>,
#  '治好': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fc50>,
#  '咳嗽': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fc88>,
#  '英文': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fcc0>,
#  '缩写': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fcf8>,
#  '石榴': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fd30>,
#  '汁': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fd68>,
#  '日常生活': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fda0>,
#  '针打': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fdd8>,
#  '之后': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fe10>,
#  '太': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fe48>,
#  '但': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fe80>,
#  '肝功': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8feb8>,
#  '甜': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8fef0>,
#  '低糖': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8ff28>,
#  '天': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8ff60>,
#  '钞票': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8ff98>,
#  '吸烟': <gensim.models.keyedvectors.Vocab at 0x7f7f29a8ffd0>,
#  '食': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94048>,
#  '蜂蜜': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94080>,
#  '判断': <gensim.models.keyedvectors.Vocab at 0x7f7f29a940b8>,
#  '转流': <gensim.models.keyedvectors.Vocab at 0x7f7f29a940f0>,
#  '肺能': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94128>,
#  '怎么样': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94160>,
#  '挤': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94198>,
#  '乳头': <gensim.models.keyedvectors.Vocab at 0x7f7f29a941d0>,
#  '液体': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94208>,
#  '溢出': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94240>,
#  '胃轻瘫': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94278>,
#  '高危': <gensim.models.keyedvectors.Vocab at 0x7f7f29a942b0>,
#  '香蕉': <gensim.models.keyedvectors.Vocab at 0x7f7f29a942e8>,
#  '前科': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94320>,
#  '晚上': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94358>,
#  '睡觉': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94390>,
#  '肾衰竭': <gensim.models.keyedvectors.Vocab at 0x7f7f29a943c8>,
#  '蚊虫': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94400>,
#  '药物': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94438>,
#  '流产': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94470>,
#  '自买': <gensim.models.keyedvectors.Vocab at 0x7f7f29a944a8>,
#  '报销': <gensim.models.keyedvectors.Vocab at 0x7f7f29a944e0>,
#  '指甲': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94518>,
#  '抓破': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94550>,
#  '抓伤': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94588>,
#  '分类': <gensim.models.keyedvectors.Vocab at 0x7f7f29a945c0>,
#  '牙龈炎': <gensim.models.keyedvectors.Vocab at 0x7f7f29a945f8>,
#  '内裤': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94630>,
#  '衣服': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94668>,
#  '鞋会': <gensim.models.keyedvectors.Vocab at 0x7f7f29a946a0>,
#  '鬼剃头': <gensim.models.keyedvectors.Vocab at 0x7f7f29a946d8>,
#  '注射用': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94710>,
#  '打开': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94748>,
#  '后变': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94780>,
#  '浑浊': <gensim.models.keyedvectors.Vocab at 0x7f7f29a947b8>,
#  '特殊': <gensim.models.keyedvectors.Vocab at 0x7f7f29a947f0>,
#  '今天': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94828>,
#  '测实': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94860>,
#  '国家': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94898>,
#  '提供': <gensim.models.keyedvectors.Vocab at 0x7f7f29a948d0>,
#  '免费': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94908>,
#  '服务': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94940>,
#  '近两天': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94978>,
#  '安排': <gensim.models.keyedvectors.Vocab at 0x7f7f29a949b0>,
#  '哪种': <gensim.models.keyedvectors.Vocab at 0x7f7f29a949e8>,
#  '一点': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94a20>,
#  '二级': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94a58>,
#  '三高': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94a90>,
#  '最佳': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94ac8>,
#  '求助': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94b00>,
#  '轻度': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94b38>,
#  '胃瘫': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94b70>,
#  '病因': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94ba8>,
#  '电子': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94be0>,
#  '或': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94c18>,
#  '水银': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94c50>,
#  '血压计': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94c88>,
#  '偏袒': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94cc0>,
#  '血脂高': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94cf8>,
#  '胆固醇': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94d30>,
#  '高龄': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94d68>,
#  '妇女': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94da0>,
#  '生命危险': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94dd8>,
#  '钱要': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94e10>,
#  '等': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94e48>,
#  '能出': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94e80>,
#  '结果': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94eb8>,
#  '穴位': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94ef0>,
#  '按摩': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94f28>,
#  '满月': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94f60>,
#  '指数': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94f98>,
#  '补牙': <gensim.models.keyedvectors.Vocab at 0x7f7f29a94fd0>,
#  '洗牙': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96048>,
#  '拔牙': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96080>,
#  '会得': <gensim.models.keyedvectors.Vocab at 0x7f7f29a960b8>,
#  '措施': <gensim.models.keyedvectors.Vocab at 0x7f7f29a960f0>,
#  '问题': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96128>,
#  '感冒药': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96160>,
#  '适合': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96198>,
#  '纤维化': <gensim.models.keyedvectors.Vocab at 0x7f7f29a961d0>,
#  '豆浆': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96208>,
#  '咋个': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96240>,
#  '食红参': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96278>,
#  '肾癌': <gensim.models.keyedvectors.Vocab at 0x7f7f29a962b0>,
#  '现有': <gensim.models.keyedvectors.Vocab at 0x7f7f29a962e8>,
#  '高血压病': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96320>,
#  '谢': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96358>,
#  '治好病': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96390>,
#  '能治去': <gensim.models.keyedvectors.Vocab at 0x7f7f29a963c8>,
#  '时候': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96400>,
#  '疗法': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96438>,
#  '颈椎病': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96470>,
#  '今年': <gensim.models.keyedvectors.Vocab at 0x7f7f29a964a8>,
#  '高压': <gensim.models.keyedvectors.Vocab at 0x7f7f29a964e0>,
#  '试纸': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96518>,
#  '检': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96550>,
#  '苦瓜': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96588>,
#  '止痛': <gensim.models.keyedvectors.Vocab at 0x7f7f29a965c0>,
#  '皮疹': <gensim.models.keyedvectors.Vocab at 0x7f7f29a965f8>,
#  '请': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96630>,
#  '帮': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96668>,
#  '解答': <gensim.models.keyedvectors.Vocab at 0x7f7f29a966a0>,
#  '听': <gensim.models.keyedvectors.Vocab at 0x7f7f29a966d8>,
#  '别人': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96710>,
#  '说': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96748>,
#  '四季': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96780>,
#  '睡眠': <gensim.models.keyedvectors.Vocab at 0x7f7f29a967b8>,
#  '可不可以': <gensim.models.keyedvectors.Vocab at 0x7f7f29a967f0>,
#  '单晶': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96828>,
#  '类型': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96860>,
#  '假性': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96898>,
#  '血小板': <gensim.models.keyedvectors.Vocab at 0x7f7f29a968d0>,
#  '概念': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96908>,
#  '荔枝': <gensim.models.keyedvectors.Vocab at 0x7f7f29a96940>,
#  ...}

# %%
w2v_model.most_similar(positive=['酸奶'])
# Out:
# /home/dutir_2t/wangchenguang/anaconda3/envs/gpu-tf/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('鸡蛋', 0.9985186457633972),
#  ('香蕉', 0.9972797632217407),
#  ('葡萄酒', 0.9968501329421997),
#  ('黄豆', 0.9963024854660034),
#  ('辣椒', 0.9950392246246338),
#  ('木糖醇', 0.9948281049728394),
#  ('小米粥', 0.9948092699050903),
#  ('喝', 0.9947265386581421),
#  ('红枣', 0.9942861795425415),
#  ('豆浆', 0.9938523769378662)]

# %%
import tensorflow as tf
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import CountVectorizer

import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1,2,3"

class Word2Vec():
    def __init__(self, w2v_size, model_type = "cbow", learning_rate = 0.025, learning_min = 1e-4, 
                 n_epochs = 1, c_of_cbow = 10, n_of_skgram = 10, min_frequency = 2):
        self.w2v_size = w2v_size
        self.model_type = model_type
        self.learning_rate = learning_rate
        self.n_epochs = n_epochs
        self.min_frequency = min_frequency
        self.model_type = model_type = model_type.lower()
        if(model_type not in ["cbow", 'skip-gram']):
            self.model_type = model_type = "cbow"
            print("model type wrong set default as cbow")
        if(model_type == "cbow"):
            self.c_of_cbow = c_of_cbow
        elif(model_type == "skip-gram"):
            self.n_of_skgram = n_of_skgram
    
    def _frequency_dict(self, words):
        dic = {}
        for line in words:
            for word in line:
                if(word in dic):
                    dic[word] += 1
                else:
                    dic[word] = 1
        return dic
    
    def _onehot_encode(self, index, max_len):
        res = np.zeros([max_len])
        if(index >= 0):
            res[index] = 1
        return res
    
    def _reduce(self, frequency_dict):
        if(self.min_frequency > 1):
            del_words = []
            for word in self.frequency_dict:
                if(self.frequency_dict[word] < self.min_frequency):
                    del_words.append(word)
            for dword in del_words:
                del self.frequency_dict[dword]
        return frequency_dict
   
    def fit(self, splited_corpus):
        self.words = [x.lower().split() for x in splited_corpus]
        self.frequency_dict = self._frequency_dict(self.words)
        self.frequency_dict = self._reduce(self.frequency_dict)
        self.vocab = list(self.frequency_dict.keys())
        self.vocab_index = {word : i for (i, word) in enumerate(self.vocab)}
        self.vovab_size = len(self.vocab)
        print('building...')
        self._build()
        print('trainning...')
        self._train()
        print('trainning Done')
        self.trained_w2v_weight = self.sess.run(self.w2v_weight)
    
    def _build(self):
        with tf.name_scope("input"):
            self.x_input = tf.placeholder(dtype=tf.float32, shape = [1, self.vovab_size], name = "input_x")
            self.y_input = tf.placeholder(dtype=tf.float32, shape = [1, self.vovab_size], name = "input_y")
        self.w2v_weight = tf.Variable(tf.random_uniform([self.vovab_size, self.w2v_size]),
                                     name = "w2v_weight")
        with tf.name_scope("present_x"):
            self.x_present = tf.matmul(self.x_input, self.w2v_weight)
            self.x_present = tf.reduce_mean(self.x_present, axis = 0)
            self.x_present = tf.expand_dims(self.x_present, 0, name = "x_present")
        with tf.name_scope("fcl"):
            self.fcl_output = tf.contrib.layers.fully_connected(self.x_present, self.vovab_size, None)
        with tf.name_scope("loss"):
            self.loss = tf.reduce_mean(
                tf.nn.softmax_cross_entropy_with_logits(
                    logits = self.fcl_output,
                    labels = self.y_input
                )
            )
        self.optimizer = tf.train.GradientDescentOptimizer(learning_rate=self.learning_rate)
        self.train_step = self.optimizer.minimize(self.loss)
    
    def vec(self, word):
        if(word not in self.vocab):
            print('word %s not in vocab maybe frequency < %d' % (word, self.min_frequency))
            return
        else:
            oh = self._word_onehot(word).reshape(1, -1).astype(np.float32)
            return self.sess.run(tf.matmul(oh, self.w2v_weight))[0]
    
    def _cos(self, vec1, vec2): 
        return np.sum(vec1 * vec2) / (np.sqrt(np.sum(vec1 * vec1)) * np.sqrt(np.sum(vec2 * vec2)))
    
    def sim(self, word1, word2):
        if(word1 not in self.vocab):
            print('word %s not in vocab maybe frequency < %d' % (word1, self.min_frequency))
            return
        elif(word2 not in self.vocab):
            print('word %s not in vocab maybe frequency < %d' % (word2, self.min_frequency))
            return
        else:
            oh1 = self._word_onehot(word1).reshape(1, -1).astype(np.float32)
            oh2 = self._word_onehot(word2).reshape(1, -1).astype(np.float32)
            vec1 = self.sess.run(tf.matmul(oh1, self.w2v_weight))[0]
            vec2 = self.sess.run(tf.matmul(oh2, self.w2v_weight))[0]
            return self._cos(vec1, vec2)
    
    def most_sim(self, word, k):
        if(word not in self.vocab):
            print('word %s not in vocab maybe frequency < %d' % (word, self.min_frequency))
            return
        else:
            oh = self._word_onehot(word).reshape(1, -1).astype(np.float32)
            vec = self.sess.run(tf.matmul(oh, self.w2v_weight))[0]
            a = vec
            b = self.trained_w2v_weight
            sims = (np.sum(a * b, axis = 1).reshape(-1, 1)) / (np.sqrt(np.sum(b*b, axis = 1).reshape(-1, 1)) * np.sqrt(np.sum(a*a)))
            sims_dict = dict(zip(self.vocab, sims.reshape(1, -1).tolist()[0]))
            #sims_dict = sorted(sims_dict, reverse = True)[1:k+1]
            sims_dict = sorted(sims_dict, reverse = True)
            print(sims_dict)
            return sims_dict
    
    def _word_onehot(self, word):
        if(word == None or word not in self.vocab):
            return self._onehot_encode(-1, self.vovab_size)
        else:
            return self._onehot_encode(self.vocab_index[word], self.vovab_size)
    
    def _extract_window_onehot(self, window, window_side_len):
        mid = self._word_onehot(window[window_side_len])
        sides = []
        for word in window[:window_side_len] + window[window_side_len + 1:]:
            sides.append(self._word_onehot(word))
        return mid, sides
    
    def _extract_window(self, line, mid_index, window_side_len):
        window = [None for i in range(2 * window_side_len + 1)]
        window_index = 0
        for index in range(mid_index - window_side_len , mid_index + window_side_len + 1):
            if(index < 0 or index >= len(line)):
                window_index += 1
                continue
            window[window_index] = line[index]
            window_index += 1
        return self._extract_window_onehot(window, window_side_len)
        #print('mid', mid_index, 'mid_word', line[mid_index], 'window', window_side_len)
        #print('line', line)
        #print(window)
    
    def _train(self):
        self.sess = tf.Session()
        self.sess.run(tf.global_variables_initializer())
        for epoch in range(self.n_epochs):
            if(self.model_type == "cbow"):
                self.c_of_cbow = np.random.randint(1, self.c_of_cbow)
                line_index = 0
                for line in self.words:
                    print('trainning line %d / %d' % (line_index, len(self.words)))
                    line_index += 1
                    for mid_index, mid_word in enumerate(line):
                        mid, sides = self._extract_window(line, mid_index, self.c_of_cbow)
                        sides_mean = np.mean(sides, axis = 0)
                        feed_dict = {
                            self.x_input : sides_mean.reshape(1, -1),
                            self.y_input : mid.reshape(1, -1)
                        }
                        self.sess.run(self.train_step, feed_dict = feed_dict)
            elif(self.model_type == "skip-gram"):
                self.n_of_skgram = np.random.randint(1, self.n_of_skgram)
                line_index = 0
                for line in self.words:
                    print('trainning line %d / %d' % (line_index, len(self.words)))
                    line_index += 1
                    for mid_index, mid_word in enumerate(line):
                        mid, sides = self._extract_window(line, mid_index, self.n_of_skgram)
                        for side in sides:
                            feed_dict = {
                                self.x_input : mid.reshape(1, -1),
                                self.y_input : side.reshape(1, -1)
                            }
                            self.sess.run(self.train_step, feed_dict = feed_dict)

            else:
                print("train error model type wrong %s" % (self.model_type))

# %%
m_w2v_model = Word2Vec(300)
m_w2v_model.fit(corpus[0:20000])
m_w2v_model.most_sim("酸奶", 100)

# %%
sm_w2v_model = Word2Vec(300, model_type="skip-gram")
sm_w2v_model.fit(corpus[0:20000])
# Out:
# building...
# trainning...
# trainning line 0 / 20000
# trainning line 1 / 20000
# trainning line 2 / 20000
# trainning line 3 / 20000
# trainning line 4 / 20000
# trainning line 5 / 20000
# trainning line 6 / 20000
# trainning line 7 / 20000
# trainning line 8 / 20000
# trainning line 9 / 20000
# trainning line 10 / 20000
# trainning line 11 / 20000
# trainning line 12 / 20000
# trainning line 13 / 20000
# trainning line 14 / 20000
# trainning line 15 / 20000
# trainning line 16 / 20000
# trainning line 17 / 20000
# trainning line 18 / 20000
# trainning line 19 / 20000
# trainning line 20 / 20000
# trainning line 21 / 20000
# trainning line 22 / 20000
# trainning line 23 / 20000
# trainning line 24 / 20000
# trainning line 25 / 20000
# trainning line 26 / 20000
# trainning line 27 / 20000
# trainning line 28 / 20000
# trainning line 29 / 20000
# trainning line 30 / 20000
# trainning line 31 / 20000
# trainning line 32 / 20000
# trainning line 33 / 20000
# trainning line 34 / 20000
# trainning line 35 / 20000
# trainning line 36 / 20000
# trainning line 37 / 20000
# trainning line 38 / 20000
# trainning line 39 / 20000
# trainning line 40 / 20000
# trainning line 41 / 20000
# trainning line 42 / 20000
# trainning line 43 / 20000
# trainning line 44 / 20000
# trainning line 45 / 20000
# trainning line 46 / 20000
# trainning line 47 / 20000
# trainning line 48 / 20000
# trainning line 49 / 20000
# trainning line 50 / 20000
# trainning line 51 / 20000
# trainning line 52 / 20000
# trainning line 53 / 20000
# trainning line 54 / 20000
# trainning line 55 / 20000
# trainning line 56 / 20000
# trainning line 57 / 20000
# trainning line 58 / 20000
# trainning line 59 / 20000
# trainning line 60 / 20000
# trainning line 61 / 20000
# trainning line 62 / 20000
# trainning line 63 / 20000
# trainning line 64 / 20000
# trainning line 65 / 20000
# trainning line 66 / 20000
# trainning line 67 / 20000
# trainning line 68 / 20000
# trainning line 69 / 20000
# trainning line 70 / 20000
# trainning line 71 / 20000
# trainning line 72 / 20000
# trainning line 73 / 20000
# trainning line 74 / 20000
# trainning line 75 / 20000
# trainning line 76 / 20000
# trainning line 77 / 20000
# trainning line 78 / 20000
# trainning line 79 / 20000
# trainning line 80 / 20000
# trainning line 81 / 20000
# trainning line 82 / 20000
# trainning line 83 / 20000
# trainning line 84 / 20000
# trainning line 85 / 20000
# trainning line 86 / 20000
# trainning line 87 / 20000
# trainning line 88 / 20000
# trainning line 89 / 20000
# trainning line 90 / 20000
# trainning line 91 / 20000
# trainning line 92 / 20000
# trainning line 93 / 20000
# trainning line 94 / 20000
# trainning line 95 / 20000
# trainning line 96 / 20000
# trainning line 97 / 20000
# trainning line 98 / 20000
# trainning line 99 / 20000
# trainning line 100 / 20000
# trainning line 101 / 20000
# trainning line 102 / 20000
# trainning line 103 / 20000
# trainning line 104 / 20000
# trainning line 105 / 20000
# trainning line 106 / 20000
# trainning line 107 / 20000
# trainning line 108 / 20000
# trainning line 109 / 20000
# trainning line 110 / 20000
# trainning line 111 / 20000
# trainning line 112 / 20000
# trainning line 113 / 20000
# trainning line 114 / 20000
# trainning line 115 / 20000
# trainning line 116 / 20000
# trainning line 117 / 20000
# trainning line 118 / 20000
# trainning line 119 / 20000
# trainning line 120 / 20000
# trainning line 121 / 20000
# trainning line 122 / 20000
# trainning line 123 / 20000
# trainning line 124 / 20000
# trainning line 125 / 20000
# trainning line 126 / 20000
# trainning line 127 / 20000
# trainning line 128 / 20000
# trainning line 129 / 20000
# trainning line 130 / 20000
# trainning line 131 / 20000
# trainning line 132 / 20000
# trainning line 133 / 20000
# trainning line 134 / 20000
# trainning line 135 / 20000
# trainning line 136 / 20000
# trainning line 137 / 20000
# trainning line 138 / 20000
# trainning line 139 / 20000
# trainning line 140 / 20000
# trainning line 141 / 20000
# trainning line 142 / 20000
# trainning line 143 / 20000
# trainning line 144 / 20000
# trainning line 145 / 20000
# trainning line 146 / 20000
# trainning line 147 / 20000
# trainning line 148 / 20000
# trainning line 149 / 20000
# trainning line 150 / 20000
# trainning line 151 / 20000
# trainning line 152 / 20000
# trainning line 153 / 20000
# trainning line 154 / 20000
# trainning line 155 / 20000
# trainning line 156 / 20000
# trainning line 157 / 20000
# trainning line 158 / 20000
# trainning line 159 / 20000
# trainning line 160 / 20000
# trainning line 161 / 20000
# trainning line 162 / 20000
# trainning line 163 / 20000
# trainning line 164 / 20000
# trainning line 165 / 20000
# trainning line 166 / 20000
# trainning line 167 / 20000
# trainning line 168 / 20000
# trainning line 169 / 20000
# trainning line 170 / 20000
# trainning line 171 / 20000
# trainning line 172 / 20000
# trainning line 173 / 20000
# trainning line 174 / 20000
# trainning line 175 / 20000
# trainning line 176 / 20000
# trainning line 177 / 20000
# trainning line 178 / 20000
# trainning line 179 / 20000
# trainning line 180 / 20000
# trainning line 181 / 20000
# trainning line 182 / 20000
# trainning line 183 / 20000
# trainning line 184 / 20000
# trainning line 185 / 20000
# trainning line 186 / 20000
# trainning line 187 / 20000
# trainning line 188 / 20000
# trainning line 189 / 20000
# trainning line 190 / 20000
# trainning line 191 / 20000
# trainning line 192 / 20000
# trainning line 193 / 20000
# trainning line 194 / 20000
# trainning line 195 / 20000
# trainning line 196 / 20000
# trainning line 197 / 20000
# trainning line 198 / 20000
# trainning line 199 / 20000
# trainning line 200 / 20000
# trainning line 201 / 20000
# trainning line 202 / 20000
# trainning line 203 / 20000
# trainning line 204 / 20000
# trainning line 205 / 20000
# trainning line 206 / 20000
# trainning line 207 / 20000
# trainning line 208 / 20000
# trainning line 209 / 20000
# trainning line 210 / 20000
# trainning line 211 / 20000
# trainning line 212 / 20000
# trainning line 213 / 20000
# trainning line 214 / 20000
# trainning line 215 / 20000
# trainning line 216 / 20000
# trainning line 217 / 20000
# trainning line 218 / 20000
# trainning line 219 / 20000
# trainning line 220 / 20000
# trainning line 221 / 20000
# trainning line 222 / 20000
# trainning line 223 / 20000
# trainning line 224 / 20000
# trainning line 225 / 20000
# trainning line 226 / 20000
# trainning line 227 / 20000
# trainning line 228 / 20000
# trainning line 229 / 20000
# trainning line 230 / 20000
# trainning line 231 / 20000
# trainning line 232 / 20000
# trainning line 233 / 20000
# trainning line 234 / 20000
# trainning line 235 / 20000
# trainning line 236 / 20000
# trainning line 237 / 20000
# trainning line 238 / 20000
# trainning line 239 / 20000
# trainning line 240 / 20000
# trainning line 241 / 20000
# trainning line 242 / 20000
# trainning line 243 / 20000
# trainning line 244 / 20000
# trainning line 245 / 20000
# trainning line 246 / 20000
# trainning line 247 / 20000
# trainning line 248 / 20000
# trainning line 249 / 20000
# trainning line 250 / 20000
# trainning line 251 / 20000
# trainning line 252 / 20000
# trainning line 253 / 20000
# trainning line 254 / 20000
# trainning line 255 / 20000
# trainning line 256 / 20000
# trainning line 257 / 20000
# trainning line 258 / 20000
# trainning line 259 / 20000
# trainning line 260 / 20000
# trainning line 261 / 20000
# trainning line 262 / 20000
# trainning line 263 / 20000
# trainning line 264 / 20000
# trainning line 265 / 20000
# trainning line 266 / 20000
# trainning line 267 / 20000
# trainning line 268 / 20000
# trainning line 269 / 20000
# trainning line 270 / 20000
# trainning line 271 / 20000
# trainning line 272 / 20000
# trainning line 273 / 20000
# trainning line 274 / 20000
# trainning line 275 / 20000
# trainning line 276 / 20000
# trainning line 277 / 20000
# trainning line 278 / 20000
# trainning line 279 / 20000
# trainning line 280 / 20000
# trainning line 281 / 20000
# trainning line 282 / 20000
# trainning line 283 / 20000
# trainning line 284 / 20000
# trainning line 285 / 20000
# trainning line 286 / 20000
# trainning line 287 / 20000
# trainning line 288 / 20000
# trainning line 289 / 20000
# trainning line 290 / 20000
# trainning line 291 / 20000
# trainning line 292 / 20000
# trainning line 293 / 20000
# trainning line 294 / 20000
# trainning line 295 / 20000
# trainning line 296 / 20000
# trainning line 297 / 20000
# trainning line 298 / 20000
# trainning line 299 / 20000
# trainning line 300 / 20000
# trainning line 301 / 20000
# trainning line 302 / 20000
# trainning line 303 / 20000
# trainning line 304 / 20000
# trainning line 305 / 20000
# trainning line 306 / 20000
# trainning line 307 / 20000
# trainning line 308 / 20000
# trainning line 309 / 20000
# trainning line 310 / 20000
# trainning line 311 / 20000
# trainning line 312 / 20000
# trainning line 313 / 20000
# trainning line 314 / 20000
# trainning line 315 / 20000
# trainning line 316 / 20000
# trainning line 317 / 20000
# trainning line 318 / 20000
# trainning line 319 / 20000
# trainning line 320 / 20000
# trainning line 321 / 20000
# trainning line 322 / 20000
# trainning line 323 / 20000
# trainning line 324 / 20000
# trainning line 325 / 20000
# trainning line 326 / 20000
# trainning line 327 / 20000
# trainning line 328 / 20000
# trainning line 329 / 20000
# trainning line 330 / 20000
# trainning line 331 / 20000
# trainning line 332 / 20000
# trainning line 333 / 20000
# trainning line 334 / 20000
# trainning line 335 / 20000
# trainning line 336 / 20000
# trainning line 337 / 20000
# trainning line 338 / 20000
# trainning line 339 / 20000
# trainning line 340 / 20000
# trainning line 341 / 20000
# trainning line 342 / 20000
# trainning line 343 / 20000
# trainning line 344 / 20000
# trainning line 345 / 20000
# trainning line 346 / 20000
# trainning line 347 / 20000
# trainning line 348 / 20000
# trainning line 349 / 20000
# trainning line 350 / 20000
# trainning line 351 / 20000
# trainning line 352 / 20000
# trainning line 353 / 20000
# trainning line 354 / 20000
# trainning line 355 / 20000
# trainning line 356 / 20000
# trainning line 357 / 20000
# trainning line 358 / 20000
# trainning line 359 / 20000
# trainning line 360 / 20000
# trainning line 361 / 20000
# trainning line 362 / 20000
# trainning line 363 / 20000
# trainning line 364 / 20000
# trainning line 365 / 20000
# trainning line 366 / 20000
# trainning line 367 / 20000
# trainning line 368 / 20000
# trainning line 369 / 20000
# trainning line 370 / 20000
# trainning line 371 / 20000
# trainning line 372 / 20000
# trainning line 373 / 20000
# trainning line 374 / 20000
# trainning line 375 / 20000
# trainning line 376 / 20000
# trainning line 377 / 20000
# trainning line 378 / 20000
# trainning line 379 / 20000
# trainning line 380 / 20000
# trainning line 381 / 20000
# trainning line 382 / 20000
# trainning line 383 / 20000
# trainning line 384 / 20000
# trainning line 385 / 20000
# trainning line 386 / 20000
# trainning line 387 / 20000
# trainning line 388 / 20000
# trainning line 389 / 20000
# trainning line 390 / 20000
# trainning line 391 / 20000
# trainning line 392 / 20000
# trainning line 393 / 20000
# trainning line 394 / 20000
# trainning line 395 / 20000
# trainning line 396 / 20000
# trainning line 397 / 20000
# trainning line 398 / 20000
# trainning line 399 / 20000
# trainning line 400 / 20000
# trainning line 401 / 20000
# trainning line 402 / 20000
# trainning line 403 / 20000
# trainning line 404 / 20000
# trainning line 405 / 20000
# trainning line 406 / 20000
# trainning line 407 / 20000
# trainning line 408 / 20000
# trainning line 409 / 20000
# trainning line 410 / 20000
# trainning line 411 / 20000
# trainning line 412 / 20000
# trainning line 413 / 20000
# trainning line 414 / 20000
# trainning line 415 / 20000
# trainning line 416 / 20000
# trainning line 417 / 20000
# trainning line 418 / 20000
# trainning line 419 / 20000
# trainning line 420 / 20000
# trainning line 421 / 20000
# trainning line 422 / 20000
# trainning line 423 / 20000
# trainning line 424 / 20000
# trainning line 425 / 20000
# trainning line 426 / 20000
# trainning line 427 / 20000
# trainning line 428 / 20000
# trainning line 429 / 20000
# trainning line 430 / 20000
# trainning line 431 / 20000
# trainning line 432 / 20000
# trainning line 433 / 20000
# trainning line 434 / 20000
# trainning line 435 / 20000
# trainning line 436 / 20000
# trainning line 437 / 20000
# trainning line 438 / 20000
# trainning line 439 / 20000
# trainning line 440 / 20000
# trainning line 441 / 20000
# trainning line 442 / 20000
# trainning line 443 / 20000
# trainning line 444 / 20000
# trainning line 445 / 20000
# trainning line 446 / 20000
# trainning line 447 / 20000
# trainning line 448 / 20000
# trainning line 449 / 20000
# trainning line 450 / 20000
# trainning line 451 / 20000
# trainning line 452 / 20000
# trainning line 453 / 20000
# trainning line 454 / 20000
# trainning line 455 / 20000
# trainning line 456 / 20000
# trainning line 457 / 20000
# trainning line 458 / 20000
# trainning line 459 / 20000
# trainning line 460 / 20000
# trainning line 461 / 20000
# trainning line 462 / 20000
# trainning line 463 / 20000
# trainning line 464 / 20000
# trainning line 465 / 20000
# trainning line 466 / 20000
# trainning line 467 / 20000
# trainning line 468 / 20000
# trainning line 469 / 20000
# trainning line 470 / 20000
# trainning line 471 / 20000
# trainning line 472 / 20000
# trainning line 473 / 20000
# trainning line 474 / 20000
# trainning line 475 / 20000
# trainning line 476 / 20000
# trainning line 477 / 20000
# trainning line 478 / 20000
# trainning line 479 / 20000
# trainning line 480 / 20000
# trainning line 481 / 20000
# trainning line 482 / 20000
# trainning line 483 / 20000
# trainning line 484 / 20000
# trainning line 485 / 20000
# trainning line 486 / 20000
# trainning line 487 / 20000
# trainning line 488 / 20000
# trainning line 489 / 20000
# trainning line 490 / 20000
# trainning line 491 / 20000
# trainning line 492 / 20000
# trainning line 493 / 20000
# trainning line 494 / 20000
# trainning line 495 / 20000
# trainning line 496 / 20000
# trainning line 497 / 20000
# trainning line 498 / 20000
# trainning line 499 / 20000
# trainning line 500 / 20000
# trainning line 501 / 20000
# trainning line 502 / 20000
# trainning line 503 / 20000
# trainning line 504 / 20000
# trainning line 505 / 20000
# trainning line 506 / 20000
# trainning line 507 / 20000
# trainning line 508 / 20000
# trainning line 509 / 20000
# trainning line 510 / 20000
# trainning line 511 / 20000
# trainning line 512 / 20000
# trainning line 513 / 20000
# trainning line 514 / 20000
# trainning line 515 / 20000
# trainning line 516 / 20000
# trainning line 517 / 20000
# trainning line 518 / 20000
# trainning line 519 / 20000
# trainning line 520 / 20000
# trainning line 521 / 20000
# trainning line 522 / 20000
# trainning line 523 / 20000
# trainning line 524 / 20000
# trainning line 525 / 20000
# trainning line 526 / 20000
# trainning line 527 / 20000
# trainning line 528 / 20000
# trainning line 529 / 20000
# trainning line 530 / 20000
# trainning line 531 / 20000
# trainning line 532 / 20000
# trainning line 533 / 20000
# trainning line 534 / 20000
# trainning line 535 / 20000
# trainning line 536 / 20000
# trainning line 537 / 20000
# trainning line 538 / 20000
# trainning line 539 / 20000
# trainning line 540 / 20000
# trainning line 541 / 20000
# trainning line 542 / 20000
# trainning line 543 / 20000
# trainning line 544 / 20000
# trainning line 545 / 20000
# trainning line 546 / 20000
# trainning line 547 / 20000
# trainning line 548 / 20000
# trainning line 549 / 20000
# trainning line 550 / 20000
# trainning line 551 / 20000
# trainning line 552 / 20000
# trainning line 553 / 20000
# trainning line 554 / 20000
# trainning line 555 / 20000
# trainning line 556 / 20000
# trainning line 557 / 20000
# trainning line 558 / 20000
# trainning line 559 / 20000
# trainning line 560 / 20000
# trainning line 561 / 20000
# trainning line 562 / 20000
# trainning line 563 / 20000
# trainning line 564 / 20000
# trainning line 565 / 20000
# trainning line 566 / 20000
# trainning line 567 / 20000
# trainning line 568 / 20000
# trainning line 569 / 20000
# trainning line 570 / 20000
# trainning line 571 / 20000
# trainning line 572 / 20000
# trainning line 573 / 20000
# trainning line 574 / 20000
# trainning line 575 / 20000
# trainning line 576 / 20000
# trainning line 577 / 20000
# trainning line 578 / 20000
# trainning line 579 / 20000
# trainning line 580 / 20000
# trainning line 581 / 20000
# trainning line 582 / 20000
# trainning line 583 / 20000
# trainning line 584 / 20000
# trainning line 585 / 20000
# trainning line 586 / 20000
# trainning line 587 / 20000
# trainning line 588 / 20000
# trainning line 589 / 20000
# trainning line 590 / 20000
# trainning line 591 / 20000
# trainning line 592 / 20000
# trainning line 593 / 20000
# trainning line 594 / 20000
# trainning line 595 / 20000
# trainning line 596 / 20000
# trainning line 597 / 20000
# trainning line 598 / 20000
# trainning line 599 / 20000
# trainning line 600 / 20000
# trainning line 601 / 20000
# trainning line 602 / 20000
# trainning line 603 / 20000
# trainning line 604 / 20000
# trainning line 605 / 20000
# trainning line 606 / 20000
# trainning line 607 / 20000
# trainning line 608 / 20000
# trainning line 609 / 20000
# trainning line 610 / 20000
# trainning line 611 / 20000
# trainning line 612 / 20000
# trainning line 613 / 20000
# trainning line 614 / 20000
# trainning line 615 / 20000
# trainning line 616 / 20000
# trainning line 617 / 20000
# trainning line 618 / 20000
# trainning line 619 / 20000
# trainning line 620 / 20000
# trainning line 621 / 20000
# trainning line 622 / 20000
# trainning line 623 / 20000
# trainning line 624 / 20000
# trainning line 625 / 20000
# trainning line 626 / 20000
# trainning line 627 / 20000
# trainning line 628 / 20000
# trainning line 629 / 20000
# trainning line 630 / 20000
# trainning line 631 / 20000
# trainning line 632 / 20000
# trainning line 633 / 20000
# trainning line 634 / 20000
# trainning line 635 / 20000
# trainning line 636 / 20000
# trainning line 637 / 20000
# trainning line 638 / 20000
# trainning line 639 / 20000
# trainning line 640 / 20000
# trainning line 641 / 20000
# trainning line 642 / 20000
# trainning line 643 / 20000
# trainning line 644 / 20000
# trainning line 645 / 20000
# trainning line 646 / 20000
# trainning line 647 / 20000
# trainning line 648 / 20000
# trainning line 649 / 20000
# trainning line 650 / 20000
# trainning line 651 / 20000
# trainning line 652 / 20000
# trainning line 653 / 20000
# trainning line 654 / 20000
# trainning line 655 / 20000
# trainning line 656 / 20000
# trainning line 657 / 20000
# trainning line 658 / 20000
# trainning line 659 / 20000
# trainning line 660 / 20000
# trainning line 661 / 20000
# trainning line 662 / 20000
# trainning line 663 / 20000
# trainning line 664 / 20000
# trainning line 665 / 20000
# trainning line 666 / 20000
# trainning line 667 / 20000
# trainning line 668 / 20000
# trainning line 669 / 20000
# trainning line 670 / 20000
# trainning line 671 / 20000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-115-7e35e165ddb1> in <module>
#       1 sm_w2v_model = Word2Vec(300, model_type="skip-gram")
# ----> 2 sm_w2v_model.fit(corpus[0:20000])
#
# <ipython-input-113-749982835ca6> in fit(self, splited_corpus)
#      60         self._build()
#      61         print('trainning...')
# ---> 62         self._train()
#      63         print('trainning Done')
#      64         self.trained_w2v_weight = self.sess.run(self.w2v_weight)
#
# <ipython-input-113-749982835ca6> in _train(self)
#     185                                 self.y_input : side.reshape(1, -1)
#     186                             }
# --> 187                             self.sess.run(self.train_step, feed_dict = feed_dict)
#     188
#     189             else:
#
# ~/anaconda3/envs/gpu-tf/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/gpu-tf/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~/anaconda3/envs/gpu-tf/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/gpu-tf/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/gpu-tf/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/envs/gpu-tf/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
sm_w2v_model.most_sim("酸奶", 100)
